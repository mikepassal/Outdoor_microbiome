# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy.stats as stats
import meteostat
import datetime

# %%
full_meta_data = pd.read_csv(
    "/Users/michael/Git/Outdoor_microbiome/Local_analysis/Plates_1_to_5_metadata.csv"
)
full_meta_data = full_meta_data.set_index("filename", drop=True)
full_meta_data = full_meta_data.drop_duplicates()
full_meta_data["Experiment Type"] = full_meta_data["timepoint"].str.split("t").str[0]
full_meta_data = full_meta_data.replace("", "Long Term")
full_meta_data = full_meta_data.replace("c1_", "Circadian Experiment 1")
full_meta_data = full_meta_data.replace("c2_", "Circadian Experiment 2")
full_meta_data["Sample Month"] = full_meta_data["date"].str.split("/").str[0]
full_meta_data = full_meta_data.replace(
    {
        "11": "November",
        "12": "December",
        "1": "January",
        "2": "February",
        "3": "March",
        "4": "April",
    }
)
full_meta_data
# Out:
#                              plate.pos  arb.sort  sampID sample.type  \
# filename
# A2450525897_n01_LICRNA01_A01       A01         1  LIC001       plant
# A2450525897_n01_LICRNA01_B01       B01         2  LIC002       plant
# A2450525897_n01_LICRNA01_C01       C01         3  LIC003       plant
# A2450525897_n01_LICRNA01_D01       D01         4  LIC004       plant
# A2450525897_n01_LICRNA01_E01       E01         5  LIC005       plant
# ...                                ...       ...     ...         ...
# A2534491401_n01_LICRNA05_D12       D12        92  LIC542       plant
# A2534491401_n01_LICRNA05_E12       E12        93  LIC495       plant
# A2534491401_n01_LICRNA05_F12       F12        94  LIC421       plant
# A2534491401_n01_LICRNA05_G12       G12        95  LIC493       plant
# A2534491401_n01_LICRNA05_H12       H12        96  LIC505       plant
#
#                              timepoint     date   time extractplate  \
# filename
# A2450525897_n01_LICRNA01_A01       t01  11/1/23   8:00       LIC_01
# A2450525897_n01_LICRNA01_B01       t01  11/1/23   8:00       LIC_01
# A2450525897_n01_LICRNA01_C01       t01  11/1/23   8:00       LIC_01
# A2450525897_n01_LICRNA01_D01       t01  11/1/23   8:00       LIC_01
# A2450525897_n01_LICRNA01_E01       t01  11/1/23   8:00       LIC_01
# ...                                ...      ...    ...          ...
# A2534491401_n01_LICRNA05_D12    c1_t13  2/11/24  20:00   LICCIRC_02
# A2534491401_n01_LICRNA05_E12    c1_t09  2/11/24   4:00   LICCIRC_02
# A2534491401_n01_LICRNA05_F12    c1_t04  2/10/24   8:00   LICCIRC_01
# A2534491401_n01_LICRNA05_G12    c1_t09  2/11/24   4:00   LICCIRC_02
# A2534491401_n01_LICRNA05_H12    c1_t10  2/11/24   8:00   LICCIRC_02
#
#                              rnaprepplate   Unmapped  Multimapping  \
# filename
# A2450525897_n01_LICRNA01_A01    LICRNA_01  2633048.0      334817.0
# A2450525897_n01_LICRNA01_B01    LICRNA_01  5074184.0      776239.0
# A2450525897_n01_LICRNA01_C01    LICRNA_01  2283008.0      427910.0
# A2450525897_n01_LICRNA01_D01    LICRNA_01  1263467.0      177674.0
# A2450525897_n01_LICRNA01_E01    LICRNA_01  3004324.0      309156.0
# ...                                   ...        ...           ...
# A2534491401_n01_LICRNA05_D12    LICRNA_05  4303811.0      813353.0
# A2534491401_n01_LICRNA05_E12    LICRNA_05  4231836.0      923444.0
# A2534491401_n01_LICRNA05_F12    LICRNA_05  4885375.0      877561.0
# A2534491401_n01_LICRNA05_G12    LICRNA_05  6078838.0      931512.0
# A2534491401_n01_LICRNA05_H12    LICRNA_05  5438007.0      945993.0
#
#                               No Feature  Ambiguous Unstranded  \
# filename
# A2450525897_n01_LICRNA01_A01    112554.0              202285.0
# A2450525897_n01_LICRNA01_B01    226718.0              494847.0
# A2450525897_n01_LICRNA01_C01     97848.0              271449.0
# A2450525897_n01_LICRNA01_D01     49095.0              123691.0
# A2450525897_n01_LICRNA01_E01    135512.0              229101.0
# ...                                  ...                   ...
# A2534491401_n01_LICRNA05_D12    383610.0              550523.0
# A2534491401_n01_LICRNA05_E12    451686.0              560171.0
# A2534491401_n01_LICRNA05_F12    360911.0              638643.0
# A2534491401_n01_LICRNA05_G12    518084.0             1005149.0
# A2534491401_n01_LICRNA05_H12    647515.0              873351.0
#
#                               Ambiguous Forward plate_row  plate_col  \
# filename
# A2450525897_n01_LICRNA01_A01            22008.0         A          1
# A2450525897_n01_LICRNA01_B01            49830.0         B          1
# A2450525897_n01_LICRNA01_C01            28416.0         C          1
# A2450525897_n01_LICRNA01_D01            13452.0         D          1
# A2450525897_n01_LICRNA01_E01            26474.0         E          1
# ...                                         ...       ...        ...
# A2534491401_n01_LICRNA05_D12            68933.0         D         12
# A2534491401_n01_LICRNA05_E12            67290.0         E         12
# A2534491401_n01_LICRNA05_F12            80102.0         F         12
# A2534491401_n01_LICRNA05_G12           113565.0         G         12
# A2534491401_n01_LICRNA05_H12           100264.0         H         12
#
#                               Total Reads  Unmapped Over Mapped  \
# filename
# A2450525897_n01_LICRNA01_A01    2248661.0              1.170940
# A2450525897_n01_LICRNA01_B01    5984566.0              0.847878
# A2450525897_n01_LICRNA01_C01    2936453.0              0.777471
# A2450525897_n01_LICRNA01_D01    1359823.0              0.929141
# A2450525897_n01_LICRNA01_E01    2680737.0              1.120708
# ...                                   ...                   ...
# A2534491401_n01_LICRNA05_D12    6510475.0              0.661059
# A2534491401_n01_LICRNA05_E12    6178604.0              0.684918
# A2534491401_n01_LICRNA05_F12    7035335.0              0.694405
# A2534491401_n01_LICRNA05_G12   11812634.0              0.514605
# A2534491401_n01_LICRNA05_H12    9668187.0              0.562464
#
#                                      Experiment Type Sample Month
# filename
# A2450525897_n01_LICRNA01_A01               Long Term     November
# A2450525897_n01_LICRNA01_B01               Long Term     November
# A2450525897_n01_LICRNA01_C01               Long Term     November
# A2450525897_n01_LICRNA01_D01               Long Term     November
# A2450525897_n01_LICRNA01_E01               Long Term     November
# ...                                              ...          ...
# A2534491401_n01_LICRNA05_D12  Circadian Experiment 1     February
# A2534491401_n01_LICRNA05_E12  Circadian Experiment 1     February
# A2534491401_n01_LICRNA05_F12  Circadian Experiment 1     February
# A2534491401_n01_LICRNA05_G12  Circadian Experiment 1     February
# A2534491401_n01_LICRNA05_H12  Circadian Experiment 1     February
#
# [480 rows x 20 columns]

# %%
rows_to_drop_expression_data = [
    "A2450525897_n01_LICRNA01_D12",
    "A2450525897_n01_undetermined",
    "A2449446903_n01_undetermined",
    "B250508004_n01_undetermined",
    "B2449500127_n01_undetermined",
    "A2534491401_n01_undetermined",
]

rows_to_drop_meta_data = ["A2450525897_n01_LICRNA01_D12"]

# %%
expression_data = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/plate1_5_tpm_normalized.csv",
    index_col=0,
)

expression_data = expression_data.drop(index=rows_to_drop_expression_data)

expression_data = expression_data.dropna(how="all", axis=0)
expression_data = expression_data.dropna(how="all", axis=1)
full_meta_data = full_meta_data.drop(index="A2450525897_n01_LICRNA01_D12")

# %%
full_meta_data = full_meta_data.sort_index()
expression_data = expression_data.sort_index()
full_meta_data
# Out:
#                              plate.pos  arb.sort  sampID sample.type  \
# filename
# A2449446903_n01_LICRNA02_A01       A01         1  LIC157       plant
# A2449446903_n01_LICRNA02_A02       A02         9  LIC169       plant
# A2449446903_n01_LICRNA02_A03       A03        17  LIC193       plant
# A2449446903_n01_LICRNA02_A04       A04        25  LIC205       plant
# A2449446903_n01_LICRNA02_A05       A05        33  LIC217       plant
# ...                                ...       ...     ...         ...
# B250508004_n01_LICRNA03_H08        H08        64  LIC428       plant
# B250508004_n01_LICRNA03_H09        H09        72  LIC440       plant
# B250508004_n01_LICRNA03_H10        H10        80  LIC452       plant
# B250508004_n01_LICRNA03_H11        H11        88  LIC464       plant
# B250508004_n01_LICRNA03_H12        H12        96  LIC488       plant
#
#                              timepoint     date   time extractplate  \
# filename
# A2449446903_n01_LICRNA02_A01       t14  1/23/24   8:00       LIC_02
# A2449446903_n01_LICRNA02_A02       t15  1/27/24   8:00       LIC_02
# A2449446903_n01_LICRNA02_A03       t17   2/2/24   8:00       LIC_03
# A2449446903_n01_LICRNA02_A04       t18   2/6/24   8:00       LIC_03
# A2449446903_n01_LICRNA02_A05       t19   2/9/24   8:00       LIC_03
# ...                                ...      ...    ...          ...
# B250508004_n01_LICRNA03_H08     c1_t04  2/10/24   8:00   LICCIRC_01
# B250508004_n01_LICRNA03_H09     c1_t05  2/10/24  12:00   LICCIRC_01
# B250508004_n01_LICRNA03_H10     c1_t06  2/10/24  16:00   LICCIRC_01
# B250508004_n01_LICRNA03_H11     c1_t07  2/10/24  20:00   LICCIRC_01
# B250508004_n01_LICRNA03_H12     c1_t08  2/11/24   0:00   LICCIRC_02
#
#                              rnaprepplate   Unmapped  Multimapping  \
# filename
# A2449446903_n01_LICRNA02_A01    LICRNA_02   758284.0      285983.0
# A2449446903_n01_LICRNA02_A02    LICRNA_02  3071877.0      648887.0
# A2449446903_n01_LICRNA02_A03    LICRNA_02  1213638.0      386660.0
# A2449446903_n01_LICRNA02_A04    LICRNA_02   306394.0      132266.0
# A2449446903_n01_LICRNA02_A05    LICRNA_02  1303436.0      170807.0
# ...                                   ...        ...           ...
# B250508004_n01_LICRNA03_H08     LICRNA_03  2552177.0      653299.0
# B250508004_n01_LICRNA03_H09     LICRNA_03  4228242.0     1225936.0
# B250508004_n01_LICRNA03_H10     LICRNA_03   365095.0      119463.0
# B250508004_n01_LICRNA03_H11     LICRNA_03   326959.0      298061.0
# B250508004_n01_LICRNA03_H12     LICRNA_03  2282102.0      976218.0
#
#                               No Feature  Ambiguous Unstranded  \
# filename
# A2449446903_n01_LICRNA02_A01     82176.0              103821.0
# A2449446903_n01_LICRNA02_A02    353549.0              398670.0
# A2449446903_n01_LICRNA02_A03    158864.0              207527.0
# A2449446903_n01_LICRNA02_A04     39209.0               46310.0
# A2449446903_n01_LICRNA02_A05     90929.0              125368.0
# ...                                  ...                   ...
# B250508004_n01_LICRNA03_H08     438552.0              460177.0
# B250508004_n01_LICRNA03_H09     493699.0              645602.0
# B250508004_n01_LICRNA03_H10      39090.0               55347.0
# B250508004_n01_LICRNA03_H11      60346.0              110795.0
# B250508004_n01_LICRNA03_H12     402777.0              438610.0
#
#                               Ambiguous Forward plate_row  plate_col  \
# filename
# A2449446903_n01_LICRNA02_A01            14939.0         A          1
# A2449446903_n01_LICRNA02_A02            57289.0         A          2
# A2449446903_n01_LICRNA02_A03            27420.0         A          3
# A2449446903_n01_LICRNA02_A04             6783.0         A          4
# A2449446903_n01_LICRNA02_A05            19337.0         A          5
# ...                                         ...       ...        ...
# B250508004_n01_LICRNA03_H08             61087.0         H          8
# B250508004_n01_LICRNA03_H09             93443.0         H          9
# B250508004_n01_LICRNA03_H10              7763.0         H         10
# B250508004_n01_LICRNA03_H11             16078.0         H         11
# B250508004_n01_LICRNA03_H12             66241.0         H         12
#
#                               Total Reads  Unmapped Over Mapped  \
# filename
# A2449446903_n01_LICRNA02_A01    1246970.0              0.608101
# A2449446903_n01_LICRNA02_A02    4985602.0              0.616150
# A2449446903_n01_LICRNA02_A03    2465662.0              0.492216
# A2449446903_n01_LICRNA02_A04     564891.0              0.542395
# A2449446903_n01_LICRNA02_A05    1515395.0              0.860130
# ...                                   ...                   ...
# B250508004_n01_LICRNA03_H08     5245242.0              0.486570
# B250508004_n01_LICRNA03_H09     7715482.0              0.548020
# B250508004_n01_LICRNA03_H10      643786.0              0.567106
# B250508004_n01_LICRNA03_H11     1509679.0              0.216575
# B250508004_n01_LICRNA03_H12     5444101.0              0.419188
#
#                                      Experiment Type Sample Month
# filename
# A2449446903_n01_LICRNA02_A01               Long Term      January
# A2449446903_n01_LICRNA02_A02               Long Term      January
# A2449446903_n01_LICRNA02_A03               Long Term     February
# A2449446903_n01_LICRNA02_A04               Long Term     February
# A2449446903_n01_LICRNA02_A05               Long Term     February
# ...                                              ...          ...
# B250508004_n01_LICRNA03_H08   Circadian Experiment 1     February
# B250508004_n01_LICRNA03_H09   Circadian Experiment 1     February
# B250508004_n01_LICRNA03_H10   Circadian Experiment 1     February
# B250508004_n01_LICRNA03_H11   Circadian Experiment 1     February
# B250508004_n01_LICRNA03_H12   Circadian Experiment 1     February
#
# [479 rows x 20 columns]

# %%
expression_data
# Out:
#                               AT1G01010  AT1G01020  AT1G03987  AT1G01030  \
# A2449446903_n01_LICRNA02_A01   0.382839  11.929183        0.0   3.731527
# A2449446903_n01_LICRNA02_A02   0.000000   5.826682        0.0   1.501594
# A2449446903_n01_LICRNA02_A03   1.021565   7.683520        0.0   0.301733
# A2449446903_n01_LICRNA02_A04   0.000000   3.525287        0.0   0.000000
# A2449446903_n01_LICRNA02_A05   0.732717   3.149144        0.0   1.947758
# ...                                 ...        ...        ...        ...
# B250508004_n01_LICRNA03_H08    0.074367   4.474710        0.0   1.383813
# B250508004_n01_LICRNA03_H09    2.232353   6.249002        0.0   1.873955
# B250508004_n01_LICRNA03_H10    0.000000   0.000000        0.0   0.000000
# B250508004_n01_LICRNA03_H11    0.678594   7.655887        0.0   0.901942
# B250508004_n01_LICRNA03_H12    0.000000   3.436049        0.0   2.004263
#
#                               AT1G01040  AT1G03993  AT1G01046  AT1G01050  \
# A2449446903_n01_LICRNA02_A01   3.602189        0.0        0.0  31.063543
# A2449446903_n01_LICRNA02_A02   3.439569        0.0        0.0  22.712417
# A2449446903_n01_LICRNA02_A03   2.700528        0.0        0.0  42.431625
# A2449446903_n01_LICRNA02_A04   3.087083        0.0        0.0  32.088437
# A2449446903_n01_LICRNA02_A05   3.742586        0.0        0.0  26.541337
# ...                                 ...        ...        ...        ...
# B250508004_n01_LICRNA03_H08    2.059206        0.0        0.0  27.907884
# B250508004_n01_LICRNA03_H09    3.869254        0.0        0.0  40.686812
# B250508004_n01_LICRNA03_H10    2.953706        0.0        0.0  36.084398
# B250508004_n01_LICRNA03_H11    4.195848        0.0        0.0  54.077818
# B250508004_n01_LICRNA03_H12    3.900086        0.0        0.0  28.479105
#
#                               AT1G03997  AT1G01060  ...  ArthCt124  ArthCr088  \
# A2449446903_n01_LICRNA02_A01        0.0   3.966935  ...  17.950907  44.209074
# A2449446903_n01_LICRNA02_A02        0.0  18.186693  ...   1.986484   9.688606
# A2449446903_n01_LICRNA02_A03        0.0  12.937632  ...   7.983340  16.384320
# A2449446903_n01_LICRNA02_A04        0.0   9.713347  ...   0.000000  40.858815
# A2449446903_n01_LICRNA02_A05        0.0  23.861601  ...  17.178143  17.005325
# ...                                 ...        ...  ...        ...        ...
# B250508004_n01_LICRNA03_H08         0.0  11.118408  ...   3.486989   4.209645
# B250508004_n01_LICRNA03_H09         0.0   7.391606  ...   9.640892   4.655562
# B250508004_n01_LICRNA03_H10         0.0   0.000000  ...   0.000000   4.975538
# B250508004_n01_LICRNA03_H11         0.0   0.334834  ...   0.000000   2.304762
# B250508004_n01_LICRNA03_H12         0.0   1.731854  ...   1.828602   5.298163
#
#                               ArthCt112  ArthCp088  ArthCp086  ArthCt118  \
# A2449446903_n01_LICRNA02_A01        0.0   0.000000        0.0        0.0
# A2449446903_n01_LICRNA02_A02        0.0   5.501032        0.0        0.0
# A2449446903_n01_LICRNA02_A03        0.0   7.983340        0.0        0.0
# A2449446903_n01_LICRNA02_A04        0.0   2.958454        0.0        0.0
# A2449446903_n01_LICRNA02_A05        0.0   0.000000        0.0        0.0
# ...                                 ...        ...        ...        ...
# B250508004_n01_LICRNA03_H08         0.0   1.072920        0.0        0.0
# B250508004_n01_LICRNA03_H09         0.0   5.085306        0.0        0.0
# B250508004_n01_LICRNA03_H10         0.0   0.000000        0.0        0.0
# B250508004_n01_LICRNA03_H11         0.0   0.000000        0.0        0.0
# B250508004_n01_LICRNA03_H12         0.0   3.657204        0.0        0.0
#
#                               ArthCp083  ArthCt111  ArthCp084  ArthCp085
# A2449446903_n01_LICRNA02_A01   0.000000        0.0   0.000000   6.266498
# A2449446903_n01_LICRNA02_A02   0.519342        0.0   0.000000   3.467317
# A2449446903_n01_LICRNA02_A03   0.166972        0.0   0.000000   0.000000
# A2449446903_n01_LICRNA02_A04   0.804390        0.0   0.000000   0.000000
# A2449446903_n01_LICRNA02_A05   0.628742        0.0   0.000000   0.000000
# ...                                 ...        ...        ...        ...
# B250508004_n01_LICRNA03_H08    0.948096        0.0   0.000000   0.760798
# B250508004_n01_LICRNA03_H09    0.360071        0.0   1.758217   4.807925
# B250508004_n01_LICRNA03_H10    0.000000        0.0   0.000000   0.000000
# B250508004_n01_LICRNA03_H11    0.166371        0.0   0.000000   0.694222
# B250508004_n01_LICRNA03_H12    0.248594        0.0   0.000000   2.553393
#
# [479 rows x 38287 columns]

# %%
full_meta_data[49:100]
# Out:
#                              plate.pos  arb.sort  sampID sample.type  \
# filename
# A2449446903_n01_LICRNA02_E02       E02        13  LIC173       plant
# A2449446903_n01_LICRNA02_E03       E03        21  LIC197       plant
# A2449446903_n01_LICRNA02_E04       E04        29  LIC209       plant
# A2449446903_n01_LICRNA02_E05       E05        37  LIC221       plant
# A2449446903_n01_LICRNA02_E06       E06        45  LIC233       plant
# A2449446903_n01_LICRNA02_E07       E07        53  LIC245       plant
# A2449446903_n01_LICRNA02_E08       E08        61  LIC257       plant
# A2449446903_n01_LICRNA02_E09       E09        69  LIC269       plant
# A2449446903_n01_LICRNA02_E10       E10        77  LIC293       plant
# A2449446903_n01_LICRNA02_E11       E11        85  LIC305       plant
# A2449446903_n01_LICRNA02_E12       E12        93  LIC317       plant
# A2449446903_n01_LICRNA02_F01       F01         6  LIC162       plant
# A2449446903_n01_LICRNA02_F02       F02        14  LIC174       plant
# A2449446903_n01_LICRNA02_F03       F03        22  LIC198       plant
# A2449446903_n01_LICRNA02_F04       F04        30  LIC210       plant
# A2449446903_n01_LICRNA02_F05       F05        38  LIC222       plant
# A2449446903_n01_LICRNA02_F06       F06        46  LIC234       plant
# A2449446903_n01_LICRNA02_F07       F07        54  LIC246       plant
# A2449446903_n01_LICRNA02_F08       F08        62  LIC258       plant
# A2449446903_n01_LICRNA02_F09       F09        70  LIC270       plant
# A2449446903_n01_LICRNA02_F10       F10        78  LIC294       plant
# A2449446903_n01_LICRNA02_F11       F11        86  LIC306       plant
# A2449446903_n01_LICRNA02_F12       F12        94  LIC318       plant
# A2449446903_n01_LICRNA02_G01       G01         7  LIC163       plant
# A2449446903_n01_LICRNA02_G02       G02        15  LIC175       plant
# A2449446903_n01_LICRNA02_G03       G03        23  LIC199       plant
# A2449446903_n01_LICRNA02_G04       G04        31  LIC211       plant
# A2449446903_n01_LICRNA02_G05       G05        39  LIC223       plant
# A2449446903_n01_LICRNA02_G06       G06        47  LIC235       plant
# A2449446903_n01_LICRNA02_G07       G07        55  LIC247       plant
# A2449446903_n01_LICRNA02_G08       G08        63  LIC259       plant
# A2449446903_n01_LICRNA02_G09       G09        71  LIC271       plant
# A2449446903_n01_LICRNA02_G10       G10        79  LIC295       plant
# A2449446903_n01_LICRNA02_G11       G11        87  LIC307       plant
# A2449446903_n01_LICRNA02_G12       G12        95  LIC319       plant
# A2449446903_n01_LICRNA02_H01       H01         8  LIC164       plant
# A2449446903_n01_LICRNA02_H02       H02        16  LIC176       plant
# A2449446903_n01_LICRNA02_H03       H03        24  LIC200       plant
# A2449446903_n01_LICRNA02_H04       H04        32  LIC212       plant
# A2449446903_n01_LICRNA02_H05       H05        40  LIC224       plant
# A2449446903_n01_LICRNA02_H06       H06        48  LIC236       plant
# A2449446903_n01_LICRNA02_H07       H07        56  LIC248       plant
# A2449446903_n01_LICRNA02_H08       H08        64  LIC260       plant
# A2449446903_n01_LICRNA02_H09       H09        72  LIC272       plant
# A2449446903_n01_LICRNA02_H10       H10        80  LIC296       plant
# A2449446903_n01_LICRNA02_H11       H11        88  LIC308       plant
# A2449446903_n01_LICRNA02_H12       H12        96  LIC320       plant
# A2450525897_n01_LICRNA01_A01       A01         1  LIC001       plant
# A2450525897_n01_LICRNA01_A02       A02         9  LIC013       plant
# A2450525897_n01_LICRNA01_A03       A03        17  LIC025       plant
# A2450525897_n01_LICRNA01_A04       A04        25  LIC037       plant
#
#                              timepoint      date  time extractplate  \
# filename
# A2449446903_n01_LICRNA02_E02       t15   1/27/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_E03       t17    2/2/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E04       t18    2/6/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E05       t19    2/9/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E06       t20   2/16/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E07       t21   2/20/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E08       t22   2/23/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E09       t23   2/26/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_E10       t25    3/5/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_E11       t26    3/8/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_E12       t27   3/12/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_F01       t14   1/23/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_F02       t15   1/27/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_F03       t17    2/2/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F04       t18    2/6/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F05       t19    2/9/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F06       t20   2/16/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F07       t21   2/20/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F08       t22   2/23/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F09       t23   2/26/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_F10       t25    3/5/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_F11       t26    3/8/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_F12       t27   3/12/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_G01       t14   1/23/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_G02       t15   1/27/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_G03       t17    2/2/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G04       t18    2/6/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G05       t19    2/9/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G06       t20   2/16/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G07       t21   2/20/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G08       t22   2/23/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G09       t23   2/26/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_G10       t25    3/5/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_G11       t26    3/8/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_G12       t27   3/12/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_H01       t14   1/23/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_H02       t15   1/27/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_H03       t17    2/2/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H04       t18    2/6/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H05       t19    2/9/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H06       t20   2/16/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H07       t21   2/20/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H08       t22   2/23/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H09       t23   2/26/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_H10       t25    3/5/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_H11       t26    3/8/24  8:00       LIC_04
# A2449446903_n01_LICRNA02_H12       t27   3/12/24  8:00       LIC_04
# A2450525897_n01_LICRNA01_A01       t01   11/1/23  8:00       LIC_01
# A2450525897_n01_LICRNA01_A02       t02   11/7/23  8:00       LIC_01
# A2450525897_n01_LICRNA01_A03       t03  11/14/23  8:00       LIC_01
# A2450525897_n01_LICRNA01_A04       t04  11/17/23  8:00       LIC_01
#
#                              rnaprepplate    Unmapped  Multimapping  \
# filename
# A2449446903_n01_LICRNA02_E02    LICRNA_02   2654140.0      717431.0
# A2449446903_n01_LICRNA02_E03    LICRNA_02   4101044.0      800490.0
# A2449446903_n01_LICRNA02_E04    LICRNA_02   1611086.0      456247.0
# A2449446903_n01_LICRNA02_E05    LICRNA_02   8275641.0     1217554.0
# A2449446903_n01_LICRNA02_E06    LICRNA_02   1492358.0      421149.0
# A2449446903_n01_LICRNA02_E07    LICRNA_02  11738506.0     1479828.0
# A2449446903_n01_LICRNA02_E08    LICRNA_02   2844142.0      456709.0
# A2449446903_n01_LICRNA02_E09    LICRNA_02   4594369.0      796450.0
# A2449446903_n01_LICRNA02_E10    LICRNA_02   1423169.0      378134.0
# A2450525897_n01_LICRNA01_A01    112554.0              202285.0
# A2450525897_n01_LICRNA01_A02     93820.0              171813.0
# A2450525897_n01_LICRNA01_A03    114403.0              201126.0
# A2450525897_n01_LICRNA01_A04    143200.0              245946.0
#
#                               Ambiguous Forward plate_row  plate_col  \
# filename
# A2449446903_n01_LICRNA02_E02            51956.0         E          2
# A2449446903_n01_LICRNA02_E03            73676.0         E          3
# A2449446903_n01_LICRNA02_E04            42841.0         E          4
# A2449446903_n01_LICRNA02_E05           117701.0         E          5
# A2449446903_n01_LICRNA02_E06            32927.0         E          6
# A2449446903_n01_LICRNA02_E07           105567.0         E          7
# A2449446903_n01_LICRNA02_E08            45821.0         E          8
# A2449446903_n01_LICRNA02_E09            67262.0         E          9
# A2449446903_n01_LICRNA02_E10            29084.0         E         10
# A2449446903_n01_LICRNA02_E11            69818.0         E         11
# A2449446903_n01_LICRNA02_E12           151328.0         E         12
# A2449446903_n01_LICRNA02_F01                NaN         F          1
# A2449446903_n01_LICRNA02_F02            64736.0         F          2
# A2449446903_n01_LICRNA02_F03            88287.0         F          3
# A2449446903_n01_LICRNA02_F04            19345.0         F          4
# A2449446903_n01_LICRNA02_F05            83089.0         F          5
# A2449446903_n01_LICRNA02_F06            44769.0         F          6
# A2449446903_n01_LICRNA02_F07            91990.0         F          7
# A2449446903_n01_LICRNA02_F08            62202.0         F          8
# A2449446903_n01_LICRNA02_F09            55878.0         F          9
# A2449446903_n01_LICRNA02_F10            17208.0         F         10
# A2449446903_n01_LICRNA02_F11            55289.0         F         11
# A2449446903_n01_LICRNA02_F12           145273.0         F         12
# A2449446903_n01_LICRNA02_G01           110431.0         G          1
# A2449446903_n01_LICRNA02_G02            41984.0         G          2
# A2449446903_n01_LICRNA02_G03            66202.0         G          3
# A2449446903_n01_LICRNA02_G04            68396.0         G          4
# A2449446903_n01_LICRNA02_G05            77685.0         G          5
# A2449446903_n01_LICRNA02_G06            53953.0         G          6
# A2449446903_n01_LICRNA02_G07            76977.0         G          7
# A2449446903_n01_LICRNA02_G08            68758.0         G          8
# A2449446903_n01_LICRNA02_G09            42477.0         G          9
# A2449446903_n01_LICRNA02_G10            24012.0         G         10
# A2449446903_n01_LICRNA02_G11            47073.0         G         11
# A2449446903_n01_LICRNA02_G12            60161.0         G         12
# A2449446903_n01_LICRNA02_H01            96681.0         H          1
# A2449446903_n01_LICRNA02_H02            65680.0         H          2
# A2449446903_n01_LICRNA02_H03            91295.0         H          3
# A2449446903_n01_LICRNA02_H04            21445.0         H          4
# A2449446903_n01_LICRNA02_H05            54310.0         H          5
# A2449446903_n01_LICRNA02_H06            38075.0         H          6
# A2449446903_n01_LICRNA02_H07            40572.0         H          7
# A2449446903_n01_LICRNA02_H08            63705.0         H          8
# A2449446903_n01_LICRNA02_H09            68108.0         H          9
# A2449446903_n01_LICRNA02_H10             5915.0         H         10
# A2449446903_n01_LICRNA02_H11            61548.0         H         11
# A2449446903_n01_LICRNA02_H12            57760.0         H         12
# A2450525897_n01_LICRNA01_A01            22008.0         A          1
# A2450525897_n01_LICRNA01_A01    2248661.0              1.170940
# A2450525897_n01_LICRNA01_A02    1942508.0              1.003497
# A2450525897_n01_LICRNA01_A03    2167043.0              1.055980
# A2450525897_n01_LICRNA01_A04    2680867.0              0.684187
#
#                              Experiment Type Sample Month
# filename
# A2449446903_n01_LICRNA02_E02       Long Term      January
# A2449446903_n01_LICRNA02_E03       Long Term     February
# A2449446903_n01_LICRNA02_E04       Long Term     February
# A2449446903_n01_LICRNA02_E05       Long Term     February
# A2449446903_n01_LICRNA02_E06       Long Term     February
# A2449446903_n01_LICRNA02_E07       Long Term     February
# A2449446903_n01_LICRNA02_E08       Long Term     February
# A2449446903_n01_LICRNA02_E09       Long Term     February
# A2449446903_n01_LICRNA02_E10       Long Term        March
# A2449446903_n01_LICRNA02_E11       Long Term        March
# A2449446903_n01_LICRNA02_E12       Long Term        March
# A2449446903_n01_LICRNA02_F01       Long Term      January
# A2449446903_n01_LICRNA02_F02       Long Term      January
# A2449446903_n01_LICRNA02_F03       Long Term     February
# A2449446903_n01_LICRNA02_F04       Long Term     February
# A2449446903_n01_LICRNA02_F05       Long Term     February
# A2449446903_n01_LICRNA02_F06       Long Term     February
# A2449446903_n01_LICRNA02_F07       Long Term     February
# A2449446903_n01_LICRNA02_F08       Long Term     February
# A2449446903_n01_LICRNA02_F09       Long Term     February
# A2449446903_n01_LICRNA02_F10       Long Term        March
# A2449446903_n01_LICRNA02_F11       Long Term        March
# A2449446903_n01_LICRNA02_F12       Long Term        March
# A2449446903_n01_LICRNA02_G01       Long Term      January
# A2449446903_n01_LICRNA02_G02       Long Term      January
# A2449446903_n01_LICRNA02_G03       Long Term     February
# A2449446903_n01_LICRNA02_G04       Long Term     February
# A2449446903_n01_LICRNA02_G05       Long Term     February
# A2449446903_n01_LICRNA02_G06       Long Term     February
# A2449446903_n01_LICRNA02_G07       Long Term     February
# A2449446903_n01_LICRNA02_G08       Long Term     February
# A2449446903_n01_LICRNA02_G09       Long Term     February
# A2449446903_n01_LICRNA02_G10       Long Term        March
# A2449446903_n01_LICRNA02_G11       Long Term        March
# A2449446903_n01_LICRNA02_G12       Long Term        March
# A2449446903_n01_LICRNA02_H01       Long Term      January
# A2449446903_n01_LICRNA02_H02       Long Term      January
# A2449446903_n01_LICRNA02_H03       Long Term     February
# A2449446903_n01_LICRNA02_H04       Long Term     February
# A2449446903_n01_LICRNA02_H05       Long Term     February
# A2449446903_n01_LICRNA02_H06       Long Term     February
# A2449446903_n01_LICRNA02_H07       Long Term     February
# A2449446903_n01_LICRNA02_H08       Long Term     February
# A2449446903_n01_LICRNA02_H09       Long Term     February
# A2449446903_n01_LICRNA02_H10       Long Term        March
# A2449446903_n01_LICRNA02_H11       Long Term        March
# A2449446903_n01_LICRNA02_H12       Long Term        March
# A2450525897_n01_LICRNA01_A01       Long Term     November
# A2450525897_n01_LICRNA01_A02       Long Term     November
# A2450525897_n01_LICRNA01_A03       Long Term     November
# A2450525897_n01_LICRNA01_A04       Long Term     November

# %%
pca = sklearn.decomposition.PCA(n_components=5).fit_transform(expression_data)
pca
# Out:
# array([[-14527.8990074 ,  -2288.99284954,  -1228.87227381,
#          -6870.08594153,  -7600.88737926],
#        [ 47178.59617875,   2489.44101612,   4291.26810568,
#          -5033.59359694,  -1627.3543993 ],
#        [ 64498.7157591 ,   4303.85190625,   6054.82020873,
#          -6516.3694974 ,  -4152.37316232],
#        ...,
#        [ 30928.6356326 , -29315.77541623,  -8369.73567639,
#          -8025.56832771,   3113.15797252],
#        [-58002.86215038,  -6041.13487499,  -7827.77629095,
#         -14752.82349408,   6024.36402688],
#        [ 14193.38195334,  35268.63114991,  11412.42651438,
#          -1285.26936549,   4191.73656699]], shape=(479, 5))

# %%
pca_model = sklearn.decomposition.PCA(n_components=5)
pca_model.fit_transform(expression_data)
pca_model.explained_variance_ratio_
# Out:
# array([0.55041651, 0.21610362, 0.12723102, 0.03500171, 0.0253482 ])

# %%
fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")
ax = sns.scatterplot(
    x=pca[:, 0],
    y=pca[:, 1],
    hue=full_meta_data["rnaprepplate"],
    style=full_meta_data["Experiment Type"],
    s=100,
    alpha=0.8,
)
plt.xlabel("PCA 1", fontsize=20)
plt.ylabel("PCA 2", fontsize=20)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize=0, rotation=90)
plt.yticks(fontsize=0)
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
# for line in range(0,full_meta_data.shape[0]):
#      ax.text(pca[:,0][line]+0.01, pca[:,1][line],
#      full_meta_data['plate.pos'][line], horizontalalignment='left',
#      size='medium', color='black', weight='semibold')

# plt.ylim(0,10)
# Out:
# (array([-400000., -300000., -200000., -100000.,       0.,  100000.,
#          200000.,  300000.,  400000.]),
#  [Text(0, -400000.0, '−400000'),
#   Text(0, -300000.0, '−300000'),
#   Text(0, -200000.0, '−200000'),
#   Text(0, -100000.0, '−100000'),
#   Text(0, 0.0, '0'),
#   Text(0, 100000.0, '100000'),
#   Text(0, 200000.0, '200000'),
#   Text(0, 300000.0, '300000'),
#   Text(0, 400000.0, '400000')])

# %%
fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")
ax = sns.scatterplot(
    x=pca[:, 0],
    y=pca[:, 1],
    hue=full_meta_data["rnaprepplate"],
    # style=full_meta_data["Time"],
    s=100,
    alpha=0.8,
)
plt.xlabel("PCA 1", fontsize=20)
plt.ylabel("PCA 2", fontsize=20)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize=0, rotation=90)
plt.yticks(fontsize=0)
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
for line in range(0, full_meta_data.shape[0]):
    ax.text(
        pca[:, 0][line] + 0.01,
        pca[:, 1][line],
        full_meta_data["plate.pos"][line],
        horizontalalignment="left",
        size="medium",
        color="black",
        weight="semibold",
    )

# plt.ylim(0,10)
# Out:
# FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
full_meta_data.loc[full_meta_data["Experiment Type"] == "Long Term"]
# Out:
#                              plate.pos  arb.sort  sampID sample.type  \
# filename
# A2449446903_n01_LICRNA02_A01       A01         1  LIC157       plant
# A2449446903_n01_LICRNA02_A02       A02         9  LIC169       plant
# A2449446903_n01_LICRNA02_A03       A03        17  LIC193       plant
# A2449446903_n01_LICRNA02_A04       A04        25  LIC205       plant
# A2449446903_n01_LICRNA02_A05       A05        33  LIC217       plant
# ...                                ...       ...     ...         ...
# B250508004_n01_LICRNA03_G04        G04        31  LIC367       plant
# B250508004_n01_LICRNA03_H01        H01         8  LIC332       plant
# B250508004_n01_LICRNA03_H02        H02        16  LIC344       plant
# B250508004_n01_LICRNA03_H03        H03        24  LIC356       plant
# B250508004_n01_LICRNA03_H04        H04        32  LIC368       plant
#
#                              timepoint     date  time extractplate  \
# filename
# A2449446903_n01_LICRNA02_A01       t14  1/23/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_A02       t15  1/27/24  8:00       LIC_02
# A2449446903_n01_LICRNA02_A03       t17   2/2/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_A04       t18   2/6/24  8:00       LIC_03
# A2449446903_n01_LICRNA02_A05       t19   2/9/24  8:00       LIC_03
# ...                                ...      ...   ...          ...
# B250508004_n01_LICRNA03_G04        t08  12/5/23  8:00       LIC_04
# B250508004_n01_LICRNA03_H01        t28  3/14/24  8:00       LIC_04
# B250508004_n01_LICRNA03_H02        t24   3/1/24  8:00       LIC_04
# B250508004_n01_LICRNA03_H03        t16  1/30/24  8:00       LIC_04
# B250508004_n01_LICRNA03_H04        t08  12/5/23  8:00       LIC_04
#
#                              rnaprepplate   Unmapped  Multimapping  \
# filename
# A2449446903_n01_LICRNA02_A01    LICRNA_02   758284.0      285983.0
# A2449446903_n01_LICRNA02_A02    LICRNA_02  3071877.0      648887.0
# A2449446903_n01_LICRNA02_A03    LICRNA_02  1213638.0      386660.0
# A2449446903_n01_LICRNA02_A04    LICRNA_02   306394.0      132266.0
# A2449446903_n01_LICRNA02_A05    LICRNA_02  1303436.0      170807.0
# ...                                   ...        ...           ...
# B250508004_n01_LICRNA03_G04     LICRNA_03  1477644.0      576615.0
# B250508004_n01_LICRNA03_H01     LICRNA_03  5963067.0     1282810.0
# B250508004_n01_LICRNA03_H02     LICRNA_03   275002.0      168251.0
# B250508004_n01_LICRNA03_H03     LICRNA_03  1718519.0      681256.0
# B250508004_n01_LICRNA03_H04     LICRNA_03  3555625.0     1246019.0
#
#                               No Feature  Ambiguous Unstranded  \
# filename
# A2449446903_n01_LICRNA02_A01     82176.0              103821.0
# A2449446903_n01_LICRNA02_A02    353549.0              398670.0
# A2449446903_n01_LICRNA02_A03    158864.0              207527.0
# A2449446903_n01_LICRNA02_A04     39209.0               46310.0
# A2449446903_n01_LICRNA02_A05     90929.0              125368.0
# ...                                  ...                   ...
# B250508004_n01_LICRNA03_G04     189073.0              233308.0
# B250508004_n01_LICRNA03_H01     589822.0              778042.0
# B250508004_n01_LICRNA03_H02      47458.0               53182.0
# B250508004_n01_LICRNA03_H03     230389.0              374600.0
# B250508004_n01_LICRNA03_H04     471419.0              532302.0
#
#                               Ambiguous Forward plate_row  plate_col  \
# filename
# A2449446903_n01_LICRNA02_A01            14939.0         A          1
# A2449446903_n01_LICRNA02_A02            57289.0         A          2
# A2449446903_n01_LICRNA02_A03            27420.0         A          3
# A2449446903_n01_LICRNA02_A04             6783.0         A          4
# A2449446903_n01_LICRNA02_A05            19337.0         A          5
# ...                                         ...       ...        ...
# B250508004_n01_LICRNA03_G04             31719.0         G          4
# B250508004_n01_LICRNA03_H01            109030.0         H          1
# B250508004_n01_LICRNA03_H02              8771.0         H          2
# B250508004_n01_LICRNA03_H03             49974.0         H          3
# B250508004_n01_LICRNA03_H04             73182.0         H          4
#
#                               Total Reads  Unmapped Over Mapped  \
# filename
# A2449446903_n01_LICRNA02_A01    1246970.0              0.608101
# A2449446903_n01_LICRNA02_A02    4985602.0              0.616150
# A2449446903_n01_LICRNA02_A03    2465662.0              0.492216
# A2449446903_n01_LICRNA02_A04     564891.0              0.542395
# A2449446903_n01_LICRNA02_A05    1515395.0              0.860130
# ...                                   ...                   ...
# B250508004_n01_LICRNA03_G04     2732871.0              0.540693
# B250508004_n01_LICRNA03_H01     9338754.0              0.638529
# B250508004_n01_LICRNA03_H02      717003.0              0.383544
# B250508004_n01_LICRNA03_H03     4705779.0              0.365193
# B250508004_n01_LICRNA03_H04     6250771.0              0.568830
#
#                              Experiment Type Sample Month
# filename
# A2449446903_n01_LICRNA02_A01       Long Term      January
# A2449446903_n01_LICRNA02_A02       Long Term      January
# A2449446903_n01_LICRNA02_A03       Long Term     February
# A2449446903_n01_LICRNA02_A04       Long Term     February
# A2449446903_n01_LICRNA02_A05       Long Term     February
# ...                                      ...          ...
# B250508004_n01_LICRNA03_G04        Long Term     December
# B250508004_n01_LICRNA03_H01        Long Term        March
# B250508004_n01_LICRNA03_H02        Long Term        March
# B250508004_n01_LICRNA03_H03        Long Term      January
# B250508004_n01_LICRNA03_H04        Long Term     December
#
# [246 rows x 20 columns]

# %%
pca
# Out:
# array([[-14527.8990074 ,  -2288.99284954,  -1228.87227381,
#          -6870.08594153,  -7600.88737926],
#        [ 47178.59617875,   2489.44101612,   4291.26810568,
#          -5033.59359694,  -1627.3543993 ],
#        [ 64498.7157591 ,   4303.85190625,   6054.82020873,
#          -6516.3694974 ,  -4152.37316232],
#        ...,
#        [ 30928.6356326 , -29315.77541623,  -8369.73567639,
#          -8025.56832771,   3113.15797252],
#        [-58002.86215038,  -6041.13487499,  -7827.77629095,
#         -14752.82349408,   6024.36402688],
#        [ 14193.38195334,  35268.63114991,  11412.42651438,
#          -1285.26936549,   4191.73656699]], shape=(479, 5))

# %%
fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")
ax = sns.scatterplot(
    x=pca[:, 0],
    y=pca[:, 1],
    hue=full_meta_data["Sample Month"],
    style=full_meta_data["Experiment Type"],
    s=100,
    alpha=0.8,
)
plt.xlabel("PCA 1", fontsize=20)
plt.ylabel("PCA 2", fontsize=20)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize=0, rotation=90)
plt.yticks(fontsize=0)
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
# for line in range(0,full_meta_data.shape[0]):
#      ax.text(pca[:,0][line]+0.01, pca[:,1][line],
#      full_meta_data['plate.pos'][line], horizontalalignment='left',
#      size='medium', color='black', weight='semibold')

# plt.ylim(0,10)
# Out:
# (array([-400000., -300000., -200000., -100000.,       0.,  100000.,
#          200000.,  300000.,  400000.]),
#  [Text(0, -400000.0, '−400000'),
#   Text(0, -300000.0, '−300000'),
#   Text(0, -200000.0, '−200000'),
#   Text(0, -100000.0, '−100000'),
#   Text(0, 0.0, '0'),
#   Text(0, 100000.0, '100000'),
#   Text(0, 200000.0, '200000'),
#   Text(0, 300000.0, '300000'),
#   Text(0, 400000.0, '400000')])

# %%
fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")
ax = sns.scatterplot(
    x=pca[:, 2],
    y=pca[:, 1],
    hue=full_meta_data["rnaprepplate"],
    style=full_meta_data["Experiment Type"],
    s=100,
    alpha=0.8,
)
plt.xlabel("PCA 3", fontsize=20)
plt.ylabel("PCA 2", fontsize=20)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize=0, rotation=90)
plt.yticks(fontsize=0)
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
for line in range(0, full_meta_data.shape[0]):
    ax.text(
        pca[:, 2][line] + 0.01,
        pca[:, 1][line],
        full_meta_data["plate.pos"][line],
        horizontalalignment="left",
        size="medium",
        color="black",
        weight="semibold",
    )

# plt.ylim(0,10)
# Out:
# FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")
ax = sns.scatterplot(
    x=pca[:, 3],
    y=pca[:, 1],
    hue=full_meta_data["rnaprepplate"],
    style=full_meta_data["Experiment Type"],
    s=100,
    alpha=0.8,
)
plt.xlabel("PCA 3", fontsize=20)
plt.ylabel("PCA 2", fontsize=20)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize=0, rotation=90)
plt.yticks(fontsize=0)
ax.plot(
    [0, 1], [0, 1], transform=ax.transAxes, linestyle="dashed", color="k", linewidth=1.5
)
for line in range(0, full_meta_data.shape[0]):
    ax.text(
        pca[:, 3][line] + 0.01,
        pca[:, 1][line],
        full_meta_data["plate.pos"][line],
        horizontalalignment="left",
        size="medium",
        color="black",
        weight="semibold",
    )

# plt.ylim(0,10)
# Out:
# FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
## Things to check - days from germination, time of sampling, weather data impact (temp, humidity, time since last rain, ) correlation of Luke data with weather data
## Worries -correlation of weather and time from germination, correlation of

# %%
stations_nearby_NYU = meteostat.Stations().nearby(40.73005, -73.99450)
stations_nearby_NYU.fetch(5)
# Out:
#                             name country region    wmo  icao  latitude  \
# id
# KJRB0     New York / Wall Street      US     NY   <NA>  KJRB   40.7012
# KNYC0  New York City / Yorkville      US     NY   <NA>  KNYC   40.7789
# 72503          LaGuardia Airport      US     NY  72503  KLGA   40.7792
# KTEB0                  Teterboro      US     NJ   <NA>  KTEB   40.8501
# 72502             Newark Airport      US     NJ  72502  KEWR   40.6825
#
#        longitude  elevation          timezone hourly_start hourly_end  \
# id
# KJRB0   -74.0090        2.0  America/New_York   2016-07-20 2026-03-10
# KNYC0   -73.9692        3.0  America/New_York   1943-12-01 2026-03-10
# 72503   -73.8800        7.0  America/New_York   1973-01-01 2026-03-10
# KTEB0   -74.0608        3.0  America/New_York   1973-01-01 2026-03-10
# 72502   -74.1694        5.0  America/New_York   1973-01-01 2026-03-10
#
#       daily_start  daily_end monthly_start monthly_end      distance
# id
# KJRB0  2016-07-21 2022-04-24    2019-01-01  2021-01-01   3432.864371
# KNYC0  1943-12-02 2022-04-24    1944-01-01  2021-01-01   5834.951677
# 72503  1939-10-07 2026-03-15    1939-01-01  2022-01-01  11085.363180
# KTEB0  1973-01-01 2022-04-24    2005-01-01  2022-01-01  14468.876601
# 72502  1843-05-01 2026-03-15    1893-01-01  2022-01-01  15662.242449

# %%
start_time = datetime.datetime(2023, 11, 1)
end_time = datetime.datetime(2024, 4, 30)
luke_apt_point = meteostat.Point(40.73005, -73.99450)
luke_hourly_data = meteostat.Hourly(luke_apt_point, start_time, end_time).fetch()

# %%
luke_hourly_data["prcp"].value_counts().head(20)
# Out:
# prcp
# 0.0    3742
# 0.2      83
# 0.3      59
# 0.4      50
# 0.1      49
# 0.5      46
# 0.7      31
# 1.0      26
# 0.6      23
# 0.9      22
# 0.8      21
# 1.2      15
# 1.1      12
# 1.5      12
# 1.3      12
# 2.0      10
# 2.5      10
# 2.3       9
# 1.8       8
# 2.7       7
# Name: count, dtype: Int64

# %%
luke_hourly_data[2400:2450]
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2024-02-09 00:00:00   6.1  -0.6  62.0   0.0  <NA>  153.0   5.4  <NA>  1025.0
# 2024-02-09 01:00:00   6.1  -0.6  62.0   0.0  <NA>  166.0   7.6  <NA>  1024.7
# 2024-02-09 02:00:00   6.7  -0.1  62.0   0.0  <NA>  158.0   9.4  <NA>  1024.5
# 2024-02-09 03:00:00   6.1   0.6  68.0   0.0  <NA>  168.0   5.4  <NA>  1024.6
# 2024-02-09 04:00:00   6.1   1.6  73.0   0.0  <NA>  240.0   5.4  <NA>  1024.6
# 2024-02-09 05:00:00   5.6   1.1  73.0   0.0  <NA>  240.0  11.2  <NA>  1024.7
# 2024-02-09 06:00:00   5.0   0.6  73.0   0.0  <NA>  220.0   5.4  <NA>  1024.0
# 2024-02-09 07:00:00   5.6  -0.7  64.0   0.2  <NA>    0.0   0.0  <NA>  1022.6
# 2024-02-09 08:00:00   5.6  -1.1  62.0   0.0  <NA>    0.0   0.0  <NA>  1022.6
# 2024-02-09 09:00:00   5.6  -1.1  62.0   0.0  <NA>  270.0   7.6  <NA>  1022.8
# 2024-02-09 10:00:00   5.6  -1.8  59.0   0.0  <NA>  290.0   7.6  <NA>  1022.5
# 2024-02-09 11:00:00   5.6  -1.8  59.0   0.0  <NA>    0.0   0.0  <NA>  1022.2
# 2024-02-09 12:00:00   5.6   0.6  70.0   0.0  <NA>    0.0   0.0  <NA>  1022.4
# 2024-02-09 13:00:00   6.1   2.7  79.0   0.0  <NA>  180.0   7.6  <NA>  1022.1
# 2024-02-09 14:00:00   6.1   3.9  86.0   0.0  <NA>  220.0  11.2  <NA>  1022.1
# 2024-02-09 15:00:00   7.2   4.0  80.0   0.0  <NA>  190.0   9.4  <NA>  1021.5
# 2024-02-09 16:00:00   8.3   4.3  76.0   0.0  <NA>  210.0  11.2  <NA>  1021.0
# 2024-02-09 17:00:00  10.6   4.5  66.0   0.0  <NA>  200.0   5.4  <NA>  1019.7
# 2024-02-09 18:00:00  11.1   4.3  63.0   0.0  <NA>  150.0  13.0  <NA>  1018.8
# 2024-02-09 19:00:00  11.1   4.3  63.0   0.0  <NA>  170.0  13.0  <NA>  1017.9
# 2024-02-09 20:00:00  11.1   5.0  66.0   0.0  <NA>  160.0  16.6  <NA>  1017.2
# 2024-04-29 02:00:00  <NA>   3.0
# 2024-04-29 03:00:00  <NA>   3.0
# 2024-04-29 04:00:00  <NA>   3.0
# 2024-04-29 05:00:00  <NA>   3.0
# 2024-04-29 06:00:00  <NA>   2.0
# 2024-04-29 07:00:00  <NA>   5.0
# 2024-04-29 08:00:00  <NA>   5.0
# 2024-04-29 09:00:00  <NA>   5.0
# 2024-04-29 10:00:00  <NA>   5.0
# 2024-04-29 11:00:00  <NA>   5.0
# 2024-04-29 12:00:00  <NA>   5.0
# 2024-04-29 13:00:00  <NA>   2.0
# 2024-04-29 14:00:00  <NA>   3.0
# 2024-04-29 15:00:00  <NA>   3.0
# 2024-04-29 16:00:00  <NA>   3.0
# 2024-04-29 17:00:00  <NA>  17.0
# 2024-04-29 18:00:00  <NA>  17.0
# 2024-04-29 19:00:00  <NA>  18.0
# 2024-04-29 20:00:00  <NA>   3.0
# 2024-04-29 21:00:00  <NA>  17.0
# 2024-04-29 22:00:00  <NA>   3.0
# 2024-04-29 23:00:00  <NA>   3.0
# 2024-04-30 00:00:00  <NA>  18.0

# %%
luke_self_collected_temp = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/lic_temp_540000007D5FFE41_031824.csv",
    skiprows=19,
)
luke_self_collected_temp
# Out:
#                  Date/Time Unit   Value
# 0      11/13/23 6:28:01 PM    C  26.621
# 1      11/13/23 8:28:01 PM    C  20.117
# 2     11/13/23 10:28:01 PM    C   8.085
# 3     11/14/23 12:28:01 AM    C   7.081
# 4      11/14/23 2:28:01 AM    C   6.579
# ...                    ...  ...     ...
# 1507    3/18/24 9:28:01 AM    C  17.613
# 1508   3/18/24 11:28:01 AM    C  21.119
# 1509    3/18/24 1:28:01 PM    C  22.620
# 1510    3/18/24 3:28:01 PM    C  22.620
# 1511    3/18/24 5:28:01 PM    C  22.620
#
# [1512 rows x 3 columns]

# %%
luke_time_data_format = "%-m/%-d/%y %-I:%-M:%S %p"
luke_self_collected_temp["Date and Time"] = datetime.datetime.strptime(
    luke_self_collected_temp["Date/Time"][0], luke_time_data_format
)
luke_self_collected_temp
# Out:
#                  Date/Time Unit   Value       Date and Time
# 0      11/13/23 6:28:01 PM    C  26.621 2023-11-13 18:28:01
# 1      11/13/23 8:28:01 PM    C  20.117 2023-11-13 18:28:01
# 2     11/13/23 10:28:01 PM    C   8.085 2023-11-13 18:28:01
# 3     11/14/23 12:28:01 AM    C   7.081 2023-11-13 18:28:01
# 4      11/14/23 2:28:01 AM    C   6.579 2023-11-13 18:28:01
# ...                    ...  ...     ...                 ...
# 1507    3/18/24 9:28:01 AM    C  17.613 2023-11-13 18:28:01
# 1508   3/18/24 11:28:01 AM    C  21.119 2023-11-13 18:28:01
# 1509    3/18/24 1:28:01 PM    C  22.620 2023-11-13 18:28:01
# 1510    3/18/24 3:28:01 PM    C  22.620 2023-11-13 18:28:01
# 1511    3/18/24 5:28:01 PM    C  22.620 2023-11-13 18:28:01
#
# [1512 rows x 4 columns]

# %%
start_time
# Out:
# datetime.datetime(2023, 11, 1, 0, 0)
