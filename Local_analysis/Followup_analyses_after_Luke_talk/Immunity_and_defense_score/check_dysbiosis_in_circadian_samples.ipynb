# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from skbio.diversity.alpha import shannon
from scipy.stats import zscore
from scipy.stats import ttest_ind

# %%
###Define Thresholds
rare_species_definition_threshold = 0.1
rare_species_abundance_threshold = 9.5
expressed_gene_reads_threshold = 2000
number_of_samples_expressed_in_threshold = 21

# %%
transcriptome = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/plate1_5_tpm_normalized.csv",
    index_col=0,
)
rows_to_drop_expression_data = [
    "A2450525897_n01_undetermined",
    "A2449446903_n01_undetermined",
    "B250508004_n01_undetermined",
    "B2449500127_n01_undetermined",
]
transcriptome = transcriptome.drop(index=rows_to_drop_expression_data)
transcriptome = transcriptome.sort_index()
metadata = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/Plates_1_to_5_metadata_merged_luke.csv",
    index_col=0,
)
metadata = metadata.drop(
    columns=[
        "arb.sort",
        "sample-id",
        "Ambiguous Unstranded",
        "Ambiguous Forward",
        "Multimapping",
        "Unmapped Over Mapped",
    ]
)
metadata["Date and Time"] = metadata["date"] + " " + metadata["time"]
luke_time_data_format = "%-m/%-d/%y %-H:%-M"
metadata["Date and Time"] = pd.to_datetime(
    metadata["Date and Time"], format=luke_time_data_format
)
unusable_samples = [
    "A2450525897_n01_LICRNA01_A06",
    "A2450525897_n01_LICRNA01_A08",
    "A2450525897_n01_LICRNA01_C11",
    "A2450525897_n01_LICRNA01_D11",
    "A2450525897_n01_LICRNA01_D12",
    "A2449446903_n01_LICRNA02_F01",
    "B2449500127_n01_LICRNA04_A04",
    "B2449500127_n01_LICRNA04_A06",
    "B2449500127_n01_LICRNA04_A07",
]
borderline_unusable = [
    "A2450525897_n01_LICRNA01_F03",
    "A2450525897_n01_LICRNA01_G07",
    "A2449446903_n01_LICRNA02_A04",
    "A2449446903_n01_LICRNA02_H10",
    "B2449500127_n01_LICRNA04_H02",
    "B2449500127_n01_LICRNA04_H11",
]
all_unsable = borderline_unusable + unusable_samples
# trimmed_transcriptome = transcriptome.drop(index=all_unsable)
# trimmed_metadata = metadata.drop(index=all_unsable)
## Get plate 5 samples and remove what they replaced from the metadata to avoid duplicates
plate_5_replacements = metadata.loc[metadata["rnaprepplate"] == "LICRNA_05"]
non_plate_5_samples = metadata.loc[metadata["rnaprepplate"] != "LICRNA_05"]
replaced_samples = non_plate_5_samples.loc[
    non_plate_5_samples["sampID"].isin(plate_5_replacements["sampID"])
]
trimmed_metadata = metadata.drop(index=replaced_samples.index)
### get duplicates and drop the one with higher total genes, so that we can drop everything from the main list
double_duplicates = (
    trimmed_metadata.loc[
        trimmed_metadata.duplicated(
            subset="sampID",
            keep=False,
        )
    ]
    .sort_values(by="Total Reads")
    .drop_duplicates(subset="sampID", keep="first")
)
trimmed_metadata = trimmed_metadata.drop(index=double_duplicates.index)
trimmed_metadata
trimmed_transcriptome = transcriptome.loc[trimmed_metadata.index]
trimmed_transcriptome
defense_gene_list = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/Generated_data/load_correlated_defense_genes_union_GO_and_FLG.csv"
)

# %%
trimmed_transcriptome
# Out:
#                               AT1G01010  AT1G01020  AT1G03987  AT1G01030  \
# filename
# A2450525897_n01_LICRNA01_A01   4.944011   1.397952        0.0   5.994827
# A2450525897_n01_LICRNA01_B01   2.911492   4.379655        0.0   2.665837
# A2450525897_n01_LICRNA01_C01   6.270921   9.657724        0.0   0.000000
# A2450525897_n01_LICRNA01_E01   3.690795   5.635420        0.0   3.786748
# A2450525897_n01_LICRNA01_F01   2.781737   8.695001        0.0   2.016710
# ...                                 ...        ...        ...        ...
# A2534491401_n01_LICRNA05_D12   0.000000   8.339930        0.0   7.860235
# A2534491401_n01_LICRNA05_E12   0.000000   1.692107        0.0   1.577446
# A2534491401_n01_LICRNA05_F12   0.641335   5.972190        0.0   1.641699
# A2534491401_n01_LICRNA05_G12   1.727665   9.030810        0.0   1.779114
# A2534491401_n01_LICRNA05_H12   0.728373   8.660978        0.0   4.130582
#
#                               AT1G01040  AT1G03993  AT1G01046  AT1G01050  \
# filename
# A2450525897_n01_LICRNA01_A01   5.876072        0.0        0.0  58.062147
# A2450525897_n01_LICRNA01_B01   3.261267        0.0        0.0  57.934612
# A2450525897_n01_LICRNA01_C01   4.158376        0.0        0.0  38.161651
# A2450525897_n01_LICRNA01_E01   2.141076        0.0        0.0  37.996762
# A2450525897_n01_LICRNA01_F01   8.565957        0.0        0.0  64.854957
# ...                                 ...        ...        ...        ...
# A2534491401_n01_LICRNA05_D12   3.199519        0.0        0.0  39.201659
# A2534491401_n01_LICRNA05_E12   3.055581        0.0        0.0  29.564231
# A2534491401_n01_LICRNA05_F12   5.632121        0.0        0.0  48.940407
# A2534491401_n01_LICRNA05_G12   5.008559        0.0        0.0  40.864049
# A2534491401_n01_LICRNA05_H12   3.850938        0.0        0.0  39.892585
#
#                               AT1G03997  AT1G01060  ...  ArthCt124  ArthCr088  \
# filename                                            ...
# A2450525897_n01_LICRNA01_A01        0.0  15.150509  ...   0.000000  13.256631
# A2450525897_n01_LICRNA01_B01        0.0  10.439273  ...   0.000000  13.734068
# A2450525897_n01_LICRNA01_C01        0.0  10.623477  ...  34.304262  31.001035
# A2450525897_n01_LICRNA01_E01        0.0   8.530523  ...   0.000000   9.676399
# A2450525897_n01_LICRNA01_F01        0.0  16.845214  ...   0.000000  67.280011
# ...                                 ...        ...  ...        ...        ...
# A2534491401_n01_LICRNA05_D12        0.0   1.057777  ...   0.000000   4.602930
# A2534491401_n01_LICRNA05_E12        0.0  12.872063  ...   0.000000   6.899039
# A2534491401_n01_LICRNA05_F12        0.0  24.612749  ...   0.000000   7.502750
# A2534491401_n01_LICRNA05_G12        0.0  24.606427  ...   0.000000   4.863406
# A2534491401_n01_LICRNA05_H12        0.0  27.409934  ...   6.830520   2.143986
#
#                               ArthCt112  ArthCp088  ArthCp086  ArthCt118  \
# filename
# A2450525897_n01_LICRNA01_A01   0.000000   0.938539        0.0        0.0
# A2450525897_n01_LICRNA01_B01   0.000000   0.350043        0.0        0.0
# A2450525897_n01_LICRNA01_C01   0.000000   0.000000        0.0        0.0
# A2450525897_n01_LICRNA01_E01   0.000000   0.000000        0.0        0.0
# A2450525897_n01_LICRNA01_F01   0.000000   0.000000        0.0        0.0
# ...                                 ...        ...        ...        ...
# A2534491401_n01_LICRNA05_D12  22.529946   1.333133        0.0        0.0
# A2534491401_n01_LICRNA05_E12   1.605254   3.951394        0.0        0.0
# A2534491401_n01_LICRNA05_F12   0.000000   1.799150        0.0        0.0
# A2534491401_n01_LICRNA05_G12   0.000000   4.041995        0.0        0.0
# A2534491401_n01_LICRNA05_H12  13.661041   4.553680        0.0        0.0
#
#                               ArthCp083  ArthCt111  ArthCp084  ArthCp085
# filename
# A2450525897_n01_LICRNA01_A01   0.956942        0.0   0.000000   1.597223
# A2450525897_n01_LICRNA01_B01   0.166556        0.0   0.000000   2.184266
# A2450525897_n01_LICRNA01_C01   0.051248        0.0   0.000000   0.855379
# A2450525897_n01_LICRNA01_E01   0.142875        0.0   0.000000   1.987260
# A2450525897_n01_LICRNA01_F01   0.496000        0.0   0.000000   0.000000
# ...                                 ...        ...        ...        ...
# A2534491401_n01_LICRNA05_D12   0.036247        0.0   4.867353   5.293749
# A2534491401_n01_LICRNA05_E12   0.839348        0.0   0.000000   3.222183
# A2534491401_n01_LICRNA05_F12   0.000000        0.0   0.000000   0.145801
# A2534491401_n01_LICRNA05_G12   0.103031        0.0   0.000000   3.821523
# A2534491401_n01_LICRNA05_H12   0.392867        0.0   0.000000   4.669592
#
# [432 rows x 38295 columns]

# %%
microbiome_abundance = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/Microbiome/lic2024_16S_rab.csv"
)
long_term_microbiome = microbiome_abundance.merge(
    metadata[["sampID", "Experiment Type"]], left_on="plantID", right_on="sampID"
)
long_term_microbiome
# Out:
#        Sample sample.type timepoint      date   time   platename  \
# 0      LIC522       plant    c1_t11   2/11/24  12:00  LICCIRC_02
# 1      LIC063       plant       t06  11/28/23   8:00      LIC_01
# 2      LIC159       plant       t14   1/23/24   8:00      LIC_02
# 3      LIC452       plant    c1_t06   2/10/24  16:00  LICCIRC_01
# 4      LIC452       plant    c1_t06   2/10/24  16:00  LICCIRC_01
# ...       ...         ...       ...       ...    ...         ...
# 15326  LIC028       plant       t03  11/14/23   8:00      LIC_01
# 15327  LIC631       plant    c2_t05    3/2/24  12:00  LICCIRC_03
# 15328  LIC712       plant    c2_t10    3/3/24   8:00  LICCIRC_04
# 15329  LIC629       plant    c2_t05    3/2/24  12:00  LICCIRC_03
# 15330  LIC230       plant       t20   2/16/24   8:00      LIC_03
#
#        daysincestart plantID      Kingdom           Phylum  \
# 0                102  LIC522  d__Bacteria   Pseudomonadota
# 1                 27  LIC063  d__Bacteria   Pseudomonadota
# 2                 83  LIC159  d__Bacteria  Cyanobacteriota
# 3                101  LIC452  d__Bacteria   Pseudomonadota
# 4                101  LIC452  d__Bacteria   Pseudomonadota
# ...              ...     ...          ...              ...
# 15326             13  LIC028  d__Bacteria   Actinomycetota
# 15327            122  LIC631  d__Bacteria   Pseudomonadota
# 15328            123  LIC712  d__Bacteria   Actinomycetota
# 15329            122  LIC629  d__Bacteria   Pseudomonadota
# 15330            107  LIC230  d__Bacteria   Pseudomonadota
#
#                      Class                     Order  \
# 0      Gammaproteobacteria  Pseudomonadales_A_650611
# 1      Alphaproteobacteria          Sphingomonadales
# 2           Cyanobacteriia          Cyanobacteriales
# 3      Gammaproteobacteria           Burkholderiales
# 4      Gammaproteobacteria           Burkholderiales
# ...                    ...                       ...
# 15326        Actinomycetes           Mycobacteriales
# 15327  Alphaproteobacteria           Caulobacterales
# 15328        Actinomycetes           Mycobacteriales
# 15329  Alphaproteobacteria        Rhizobiales_505101
# 15330  Alphaproteobacteria        Rhizobiales_505101
#
#                           Family                  Genus  \
# 0               Pseudomonadaceae   Pseudomonas_E_647464
# 1       Sphingomonadaceae_486827  Sphingomonas_L_486704
# 2             Coleofasciculaceae                Caldora
# 3      Burkholderiaceae_A_595421        Massilia_574544
# 4      Burkholderiaceae_A_595421        Massilia_574544
# ...                          ...                    ...
# 15326        Geodermatophilaceae          Modestobacter
# 15327           Caulobacteraceae          Brevundimonas
# 15328        Geodermatophilaceae                Klenkia
# 15329               Rhizobiaceae          Agrobacterium
# 15330           Beijerinckiaceae       Methylobacterium
#
#                                  Species  AbundR100  sampID  \
# 0       Pseudomonas_E_647464 viridiflava       79.1  LIC522
# 1      Sphingomonas_L_486704 sp000786205       66.1  LIC063
# 2                    Caldora sp010672925       60.5  LIC159
# 3                  Massilia atriviolacea       59.8  LIC452
# 4                  Massilia atriviolacea       59.8  LIC452
# ...                                  ...        ...     ...
# 15326              Modestobacter muralis        0.5  LIC028
# 15327        Brevundimonas subvibrioides        0.5  LIC631
# 15328                Klenkia sp001424455        0.5  LIC712
# 15329          Agrobacterium larrymoorei        0.5  LIC629
# 15330       Methylobacterium sp001424705        0.5  LIC230
#
#               Experiment Type
# 0      Circadian Experiment 1
# 1                   Long Term
# 2                   Long Term
# 3      Circadian Experiment 1
# 4      Circadian Experiment 1
# ...                       ...
# 15326               Long Term
# 15327  Circadian Experiment 2
# 15328  Circadian Experiment 2
# 15329  Circadian Experiment 2
# 15330               Long Term
#
# [15331 rows x 18 columns]

# %%
species_abundance_table = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/Generated_data/species_core_results.csv"
)
species_abundance_table
# Out:
#                                Species  n_samples_present  \
# 0              Kordiimonas sp002401685                372
# 1    Sphingomonas_L_486704 sp000786205                372
# 2               Rhodoferax_C aquaticus                370
# 3                    Neorhizobium soli                366
# 4                  Klenkia sp001424455                363
# ..                                 ...                ...
# 274                Tardiphaga robiniae                  1
# 275                   Telluria timonae                  1
# 276                UBA4416 sp002420145                  1
# 277                Umezawaea tangerina                  1
# 278               Xenophilus aerolatus                  1
#
#      mean_abundance_present  median_abundance_present  prevalence   core
# 0                  3.661053                      3.30    1.000000   True
# 1                 17.954211                     15.90    1.000000   True
# 2                  4.407143                      3.70    0.994624   True
# 3                  3.855080                      2.25    0.983871   True
# 4                  3.581402                      2.70    0.975806   True
# ..                      ...                       ...         ...    ...
# 274                0.500000                      0.50    0.002688  False
# 275               10.800000                     10.80    0.002688  False
# 276                0.700000                      0.70    0.002688  False
# 277                1.100000                      1.10    0.002688  False
# 278                1.000000                      1.00    0.002688  False
#
# [279 rows x 6 columns]

# %%
species_abundance_table["rare"] = False
species_abundance_table.loc[
    species_abundance_table["n_samples_present"] <= 37, "rare"
] = True
species_abundance_table
# Out:
#                                Species  n_samples_present  \
# 0              Kordiimonas sp002401685                372
# 1    Sphingomonas_L_486704 sp000786205                372
# 2               Rhodoferax_C aquaticus                370
# 3                    Neorhizobium soli                366
# 4                  Klenkia sp001424455                363
# ..                                 ...                ...
# 274                Tardiphaga robiniae                  1
# 275                   Telluria timonae                  1
# 276                UBA4416 sp002420145                  1
# 277                Umezawaea tangerina                  1
# 278               Xenophilus aerolatus                  1
#
#      mean_abundance_present  median_abundance_present  prevalence   core  \
# 0                  3.661053                      3.30    1.000000   True
# 1                 17.954211                     15.90    1.000000   True
# 2                  4.407143                      3.70    0.994624   True
# 3                  3.855080                      2.25    0.983871   True
# 4                  3.581402                      2.70    0.975806   True
# ..                      ...                       ...         ...    ...
# 274                0.500000                      0.50    0.002688  False
# 275               10.800000                     10.80    0.002688  False
# 276                0.700000                      0.70    0.002688  False
# 277                1.100000                      1.10    0.002688  False
# 278                1.000000                      1.00    0.002688  False
#
#       rare
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 274   True
# 275   True
# 276   True
# 277   True
# 278   True
#
# [279 rows x 7 columns]

# %%
list_of_rare_species = species_abundance_table.loc[
    species_abundance_table["rare"] == True, "Species"
].tolist()
list_of_core_species = species_abundance_table.loc[
    species_abundance_table["core"] == True, "Species"
].tolist()
list_of_rare_species
# Out:
# ['Bradyrhizobium sp000938255',
#  'Noviherbaspirillum_A_568104 psychrotolerans',
#  'Brevundimonas huaxiensis',
#  'Mycobacterium paragordonae',
#  'Aeromicrobium sp001426485',
#  'Marmoricola_A_392027 sp001424755',
#  'Flavobacterium sangjuense',
#  'Herbaspirillum robiniae',
#  'Hylemonella sp001432305',
#  'Telluria mixta',
#  'Undibacterium arcticum',
#  'Brevundimonas sp001424025',
#  'Herminiimonas arsenicoxydans',
#  'Amnibacterium kyonggiense',
#  'Patulibacter minatonensis',
#  'Aquabacterium_A_592457 parvum',
#  'Chioneia frigida',
#  'Curtobacterium sp001422205',
#  'Kineosporia rhamnosa',
#  'Pseudonocardia hierapolitana',
#  'Nakamurella panacisegetis',
#  'Curvibacter gracilis',
#  'Agrobacterium rubi',
#  'Nocardioides_A_392796 ginsengisegetis',
#  'Pseudoduganella namucuonensis',
#  'Pseudomonas_E_647464 rhizosphaerae',
#  'Actinoplanes rectilineatus',
#  'Microbacterium_A_383321 testaceum_F',
#  'Actinoplanes globisporus',
#  'Herbaspirillum seropedicae',
#  'Methylophilus methylotrophus',
#  'Pseudomonas_E_647626 sp900573885',
#  'Aeromicrobium sp001428805',
#  'Microbacterium_A_383321 lemovicicum',
#  'Nakamurella lactea',
#  'Sphingomonas_L_486704 elodea',
#  'Pelomonas saccharophila',
#  'Sphingomonas_L_486704 lenta',
#  'Sphingomonas_L_486704 sp000382485',
#  'Cryptosporangium arvum',
#  'Herbiconiux flava',
#  'Homoserinimonas sp008001035',
#  'Methylotenera_A_557637 sp000799735',
#  'Microbacterium_A_383321 profundi',
#  'Nocardioides_A_392796 alkalitolerans',
#  'Stutzerimonas urumqiensis',
#  'Brevundimonas bacteroides',
#  'Nocardioides marmoriterrae',
#  'Nocardioides_A_392796 hankookensis',
#  'Nocardioides_A_392796 terrae',
#  'Polaromonas sp002001015',
#  'Pseudomonas_E_647464 pisciculturae',
#  'Rhizobium_C_501058 metallidurans',
#  'Pseudonocardia seranimata',
#  'Blastococcus capsensis',
#  'DSM-44207 sp900101335',
#  'Duganella aquatica',
#  'Rhizobium_C_501058 grahamii',
#  'Sphingomonas_L_486704 mali',
#  'UBA1952 sp004144185',
#  'Agreia bicolorata',
#  'Aureimonas_A_501548 sp001423245',
#  'Microbacterium_A_383321 luteum',
#  'Nakamurella multipartita',
#  'Nocardioides_A_392796 psychrotolerans',
#  'Rugamonas rubra',
#  'Sphingomonas_L_486704 insulae',
#  'Sphingomonas_R_483406 montana',
#  'Telluria brevitalea',
#  'Devosia_A_502124 sp001426345',
#  'Labilithrix luteola',
#  'Modestobacter muralis',
#  'Neorhizobium sp900469445',
#  'Noviherbaspirillum_A_568106 aurantiacum',
#  'Sphingomonas_L_486704 olei',
#  'Sphingomonas_L_486704 sp001421355',
#  'Brevundimonas denitrificans',
#  'Caulobacter soli',
#  'Methylobacterium radiotolerans',
#  'Motilibacter_A rhizosphaerae',
#  'Telluria sp000745265',
#  'Aldersonia kunmingensis',
#  'Aquabacterium_A_591266 sp002198735',
#  'Flavobacterium gilvum',
#  'Noviherbaspirillum_A_569121 massiliense',
#  'Sphingomonas_L_486704 aracearum',
#  'Uliginosibacterium sediminicola',
#  'Aeromicrobium sp001423335',
#  'Amycolatopsis_D_380400 oliviviridis',
#  'Baekduia woesei_A',
#  'Bosea sp011764485',
#  'Buchnera aphidicola_E',
#  'Flavobacterium akiainvivens',
#  'Microlunatus_B parietis',
#  'Naasia flava',
#  'Nakamurella albus',
#  'Nocardioides_A_392796 cynanchi',
#  'Pseudorhodoferax sp001422445',
#  'Rhizobacter sp001425825',
#  'Rhodoferax_C lacus',
#  'UBA5216 sp902825845',
#  'Virgisporangium myanmarense',
#  'Abditibacterium utsteinense',
#  'Arthrobacter ureafaciens',
#  'Arthrobacter_E_385777 globiformis',
#  'Caballeronia pedi',
#  'Chryseobacterium_A_795111 sp001507335',
#  'Chryseobacterium_A_796612 daeguense',
#  'Chryseobacterium_A_796612 sp000333355',
#  'Conyzicola nivalis',
#  'Flavobacterium antarcticum',
#  'Flavobacterium cellulosilyticum',
#  'Inhella proteolytica',
#  'Labedella gwakjiensis',
#  'Methylobacterium organophilum',
#  'Methylobacterium thiocyanatum',
#  'Motilibacter_A deserti',
#  'Phenylobacterium sp002256425',
#  'Pseudoduganella rivuli',
#  'Pseudomonas_O kuykendallii',
#  'Pseudonocardia asaccharolytica',
#  'Pseudonocardia thermophila',
#  'Rhizorhabdus argentea',
#  'AVCC01 sp000622895',
#  'Actinocorallia herbida',
#  'Aureimonas_A_501549 ferruginea',
#  'Bosea caraganae',
#  'Bosea massiliensis',
#  'Bradyrhizobium sp000244915',
#  'Caballeronia fortuita',
#  'Caulobacter henricii',
#  'Caulobacter vibrioides_C_487720',
#  'Dankookia rubra',
#  'Ga0074137 sp001464715',
#  'Geodermatophilus sp000701365',
#  'Janthinobacterium sp000344615',
#  'Jatrophihabitans_A_372606 huperziae',
#  'Kineosporia aurantiaca',
#  'Methylobacterium brachiatum',
#  'Methylobacterium sp000372825',
#  'Micromonospora_H_372070 lutea',
#  'Mycobacterium aromaticivorans',
#  'Nocardioides_A massiliensis',
#  'Nocardioides_A_392796 albus',
#  'Patulibacter ginsengiterrae',
#  'Pedococcus sp001429605',
#  'Pseudokineococcus basanitobsidens',
#  'Pseudomonas_E_647464 lutea',
#  'Pseudomonas_E_647464 siliginis',
#  'Rathayibacter sp001423885',
#  'Terracoccus luteus',
#  'Williamsia_A deligens',
#  'Actinoallomurus bryophytorum',
#  'Actinomycetospora succinea',
#  'Agrococcus jejuensis',
#  'Allorhizobium sp900176345',
#  'Alsobacter soli',
#  'Amnibacterium endophyticum',
#  'Aquabacterium_A_592457 soli',
#  'Arsenicicoccus dermatophilus',
#  'Arthrobacter chlorophenolicus',
#  'Asticcacaulis solisilvae',
#  'Aureimonas_A_501548 galii',
#  'Brevundimonas humi',
#  'Brevundimonas sp001425945',
#  'Catenuloplanes crispus',
#  'Cellvibrio zantedeschiae',
#  'Chryseobacterium_A_796612 arachidis',
#  'Clavibacter sepedonicus',
#  'Croceibacterium mercuriale',
#  'Flavobacterium hauense',
#  'Granulicoccus phenolivorans',
#  'Gryllotalpicola ginsengisoli',
#  'Herbiconiux moechotypicola',
#  'Herbiconiux solani',
#  'Kocuria polaris',
#  'Kutzneria kofuensis',
#  'Limnohabitans_A planktonicus',
#  'Marihabitans melonis',
#  'Marmoricola_A_392027 ginsengisoli',
#  'Massilia polaris',
#  'Mesorhizobium_I ciceri',
#  'Methylobacterium durans',
#  'Micromonospora_H_372070 siamensis',
#  'Nakamurella silvestris',
#  'Nocardioides_A_392796 allogilvus',
#  'Nocardioides_A_392796 jishulii',
#  'Nocardioides_A_392796 sp000015265',
#  'Nocardioides_A_392796 sp000364605',
#  'Nocardioides_A_392796 sp001429625',
#  'Paraburkholderia sprentiae',
#  'Paracidovorax avenae',
#  'Paraherbaspirillum soli',
#  'Pararhizobium_B_499893 sp001424985',
#  'Phenylobacterium soli',
#  'Phytohabitans suffuscus',
#  'Pseudoclavibacter_C sp002931055',
#  'Pseudoduganella sp001191005',
#  'Rhizobium_C_501058 mesoamericanum',
#  'Roseateles depolymerans',
#  'Roseomonas rosea',
#  'Roseomonas sp001941945',
#  'Solirubrobacter sp000425945',
#  'Sphingomonas_L_486704 hengshuiensis',
#  'Sphingomonas_L_486704 soli',
#  'Sphingomonas_L_486704 sp001421995',
#  'Stenotrophomonas_A_615274 rhizophila',
#  'Streptomyces acidiscabies',
#  'Streptomyces sp001298575',
#  'Tardiphaga robiniae',
#  'Telluria timonae',
#  'UBA4416 sp002420145',
#  'Umezawaea tangerina',
#  'Xenophilus aerolatus']

# %%
# For each sample, check if it has any rare species or is lacking any core species
rare_species_set = set(list_of_rare_species)
core_species_set = set(list_of_core_species)

# Get species-level summaries for each sample (using sampID from long_term_microbiome)
sample_species = long_term_microbiome.groupby("sampID")["Species"].apply(set)
sample_timepoint = long_term_microbiome.groupby("sampID")["timepoint"].first()
total_species_present = sample_species.apply(len)
core_species_present_count = sample_species.apply(
    lambda species: len(species & core_species_set)
)

# Compute Shannon diversity from each sample's species abundance profile
sample_shannon = (
    long_term_microbiome.loc[:, ["sampID", "Species", "AbundR100"]]
    .assign(
        AbundR100=lambda d: pd.to_numeric(d["AbundR100"], errors="coerce").fillna(0.0)
    )
    .groupby(["sampID", "Species"], sort=False)["AbundR100"]
    .sum()
    .groupby(level=0, sort=False)
    .apply(lambda abundances: shannon(abundances.to_numpy()))
    .rename("shannon_diversity")
)

# Check if sample has any rare species
has_rare_species = sample_species.apply(lambda x: len(x & rare_species_set) > 0)

# Check if sample is lacking any core species (missing at least one core species)
lacking_core_species = sample_species.apply(lambda x: not core_species_set.issubset(x))

# Total relative abundance of rare species per sample (sum of AbundR100 over rare species)
rare_abund_by_sample = (
    long_term_microbiome.loc[
        long_term_microbiome["Species"].isin(rare_species_set),
        ["sampID", "AbundR100"],
    ]
    .assign(
        AbundR100=lambda d: pd.to_numeric(d["AbundR100"], errors="coerce").fillna(
            0.0
        )  ##Junky column that just makes sure that its numeric
    )
    .groupby("sampID", sort=False)["AbundR100"]
    .sum()
    .rename("rare_species_total_abundR100")
)

# Add columns to metadata using the sampID column (not the index)
trimmed_metadata["timepoint"] = trimmed_metadata["sampID"].map(sample_timepoint)
trimmed_metadata["shannon_diversity"] = (
    trimmed_metadata["sampID"].map(sample_shannon).fillna(0.0)
)
trimmed_metadata["total_species_present"] = trimmed_metadata["sampID"].map(
    lambda sample_id: int(total_species_present.get(sample_id, 0))
)
trimmed_metadata["n_core_species_present"] = trimmed_metadata["sampID"].map(
    lambda sample_id: int(core_species_present_count.get(sample_id, 0))
)
trimmed_metadata["has_rare_species"] = trimmed_metadata["sampID"].map(
    lambda sample_id: bool(has_rare_species.get(sample_id, False))
)
trimmed_metadata["lacking_core_species"] = trimmed_metadata["sampID"].map(
    lambda sample_id: bool(lacking_core_species.get(sample_id, True))
)
trimmed_metadata["rare_species_total_abundR100"] = (
    trimmed_metadata["sampID"].map(rare_abund_by_sample).fillna(0.0)
)

trimmed_metadata[
    [
        "sampID",
        "timepoint",
        "shannon_diversity",
        "total_species_present",
        "n_core_species_present",
        "has_rare_species",
        "lacking_core_species",
        "rare_species_total_abundR100",
    ]
]
# Out:
#                               sampID timepoint  shannon_diversity  \
# filename
# A2450525897_n01_LICRNA01_A01  LIC001       t01           3.372162
# A2450525897_n01_LICRNA01_B01  LIC002       t01           3.318174
# A2450525897_n01_LICRNA01_C01  LIC003       t01           3.624092
# A2450525897_n01_LICRNA01_E01  LIC005       t01           2.368151
# A2450525897_n01_LICRNA01_F01  LIC006       t01           2.417881
# ...                              ...       ...                ...
# A2534491401_n01_LICRNA05_D12  LIC542    c1_t13           3.449391
# A2534491401_n01_LICRNA05_E12  LIC495    c1_t09           2.617054
# A2534491401_n01_LICRNA05_F12  LIC421    c1_t04           2.973997
# A2534491401_n01_LICRNA05_G12  LIC493    c1_t09           2.894683
# A2534491401_n01_LICRNA05_H12  LIC505    c1_t10           2.581557
#
#                               total_species_present  n_core_species_present  \
# filename
# A2450525897_n01_LICRNA01_A01                     49                      10
# A2450525897_n01_LICRNA01_B01                     51                       9
# A2450525897_n01_LICRNA01_C01                     49                      10
# A2450525897_n01_LICRNA01_E01                     31                       9
# A2450525897_n01_LICRNA01_F01                     28                       7
# ...                                             ...                     ...
# A2534491401_n01_LICRNA05_D12                     51                      10
# A2534491401_n01_LICRNA05_E12                     35                       8
# A2534491401_n01_LICRNA05_F12                     33                      10
# A2534491401_n01_LICRNA05_G12                     40                      10
# A2534491401_n01_LICRNA05_H12                     33                       9
#
#                               has_rare_species  lacking_core_species  \
# filename
# A2450525897_n01_LICRNA01_A01              True                 False
# A2450525897_n01_LICRNA01_B01              True                  True
# A2450525897_n01_LICRNA01_C01              True                 False
# A2450525897_n01_LICRNA01_E01              True                  True
# A2450525897_n01_LICRNA01_F01              True                  True
# ...                                        ...                   ...
# A2534491401_n01_LICRNA05_D12              True                 False
# A2534491401_n01_LICRNA05_E12              True                  True
# A2534491401_n01_LICRNA05_F12              True                 False
# A2534491401_n01_LICRNA05_G12              True                 False
# A2534491401_n01_LICRNA05_H12              True                  True
#
#                               rare_species_total_abundR100
# filename
# A2450525897_n01_LICRNA01_A01                          11.7
# A2450525897_n01_LICRNA01_B01                          20.8
# A2450525897_n01_LICRNA01_C01                          34.0
# A2450525897_n01_LICRNA01_E01                           5.3
# A2450525897_n01_LICRNA01_F01                          16.0
# ...                                                    ...
# A2534491401_n01_LICRNA05_D12                          16.2
# A2534491401_n01_LICRNA05_E12                          38.0
# A2534491401_n01_LICRNA05_F12                           8.0
# A2534491401_n01_LICRNA05_G12                          13.0
# A2534491401_n01_LICRNA05_H12                           7.0
#
# [432 rows x 8 columns]

# %%
trimmed_metadata["Dysbiosis Status"] = "Not Dysbiotic"
trimmed_metadata.loc[
    trimmed_metadata["rare_species_total_abundR100"] > rare_species_abundance_threshold,
    "Dysbiosis Status",
] = "Dysbiotic"
trimmed_metadata
# Out:
#                              plate.pos  sampID sample.type timepoint     date  \
# filename
# A2450525897_n01_LICRNA01_A01       A01  LIC001       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_B01       B01  LIC002       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_C01       C01  LIC003       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_E01       E01  LIC005       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_F01       F01  LIC006       plant       t01  11/1/23
# ...                                ...     ...         ...       ...      ...
# A2534491401_n01_LICRNA05_D12       D12  LIC542       plant    c1_t13  2/11/24
# A2534491401_n01_LICRNA05_E12       E12  LIC495       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_F12       F12  LIC421       plant    c1_t04  2/10/24
# A2534491401_n01_LICRNA05_G12       G12  LIC493       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_H12       H12  LIC505       plant    c1_t10  2/11/24
#
#                                time extractplate rnaprepplate   Unmapped  \
# filename
# A2450525897_n01_LICRNA01_A01   8:00       LIC_01    LICRNA_01  2633048.0
# A2450525897_n01_LICRNA01_B01   8:00       LIC_01    LICRNA_01  5074184.0
# A2450525897_n01_LICRNA01_C01   8:00       LIC_01    LICRNA_01  2283008.0
# A2450525897_n01_LICRNA01_E01   8:00       LIC_01    LICRNA_01  3004324.0
# A2450525897_n01_LICRNA01_F01   8:00       LIC_01    LICRNA_01  4577311.0
# ...                             ...          ...          ...        ...
# A2534491401_n01_LICRNA05_D12  20:00   LICCIRC_02    LICRNA_05  4303811.0
# A2534491401_n01_LICRNA05_E12   4:00   LICCIRC_02    LICRNA_05  4231836.0
# A2534491401_n01_LICRNA05_F12   8:00   LICCIRC_01    LICRNA_05  4885375.0
# A2534491401_n01_LICRNA05_G12   4:00   LICCIRC_02    LICRNA_05  6078838.0
# A2534491401_n01_LICRNA05_H12   8:00   LICCIRC_02    LICRNA_05  5438007.0
#
#                               No Feature  ... Sample Month  daysincestart  \
# filename                                  ...
# A2450525897_n01_LICRNA01_A01    112554.0  ...     November              0
# A2450525897_n01_LICRNA01_B01    226718.0  ...     November              0
# A2450525897_n01_LICRNA01_C01     97848.0  ...     November              0
# A2450525897_n01_LICRNA01_E01    135512.0  ...     November              0
# A2450525897_n01_LICRNA01_F01    113185.0  ...     November              0
# ...                                  ...  ...          ...            ...
# A2534491401_n01_LICRNA05_D12    383610.0  ...     February            102
# A2534491401_n01_LICRNA05_E12    451686.0  ...     February            102
# A2534491401_n01_LICRNA05_F12    360911.0  ...     February            101
# A2534491401_n01_LICRNA05_G12    518084.0  ...     February            102
# A2534491401_n01_LICRNA05_H12    647515.0  ...     February            102
#
#                                    Date and Time shannon_diversity  \
# filename
# A2450525897_n01_LICRNA01_A01 2023-11-01 08:00:00          3.372162
# A2450525897_n01_LICRNA01_B01 2023-11-01 08:00:00          3.318174
# A2450525897_n01_LICRNA01_C01 2023-11-01 08:00:00          3.624092
# A2450525897_n01_LICRNA01_E01 2023-11-01 08:00:00          2.368151
# A2450525897_n01_LICRNA01_F01 2023-11-01 08:00:00          2.417881
# ...                                          ...               ...
# A2534491401_n01_LICRNA05_D12 2024-02-11 20:00:00          3.449391
# A2534491401_n01_LICRNA05_E12 2024-02-11 04:00:00          2.617054
# A2534491401_n01_LICRNA05_F12 2024-02-10 08:00:00          2.973997
# A2534491401_n01_LICRNA05_G12 2024-02-11 04:00:00          2.894683
# A2534491401_n01_LICRNA05_H12 2024-02-11 08:00:00          2.581557
#
#                              total_species_present  n_core_species_present  \
# filename
# A2450525897_n01_LICRNA01_A01                    49                      10
# A2450525897_n01_LICRNA01_B01                    51                       9
# A2450525897_n01_LICRNA01_C01                    49                      10
# A2450525897_n01_LICRNA01_E01                    31                       9
# A2450525897_n01_LICRNA01_F01                    28                       7
# ...                                            ...                     ...
# A2534491401_n01_LICRNA05_D12                    51                      10
# A2534491401_n01_LICRNA05_E12                    35                       8
# A2534491401_n01_LICRNA05_F12                    33                      10
# A2534491401_n01_LICRNA05_G12                    40                      10
# A2534491401_n01_LICRNA05_H12                    33                       9
#
#                              has_rare_species  lacking_core_species  \
# filename
# A2450525897_n01_LICRNA01_A01             True                 False
# A2450525897_n01_LICRNA01_B01             True                  True
# A2450525897_n01_LICRNA01_C01             True                 False
# A2450525897_n01_LICRNA01_E01             True                  True
# A2450525897_n01_LICRNA01_F01             True                  True
# ...                                       ...                   ...
# A2534491401_n01_LICRNA05_D12             True                 False
# A2534491401_n01_LICRNA05_E12             True                  True
# A2534491401_n01_LICRNA05_F12             True                 False
# A2534491401_n01_LICRNA05_G12             True                 False
# A2534491401_n01_LICRNA05_H12             True                  True
#
#                               rare_species_total_abundR100  Dysbiosis Status
# filename
# A2450525897_n01_LICRNA01_A01                          11.7         Dysbiotic
# A2450525897_n01_LICRNA01_B01                          20.8         Dysbiotic
# A2450525897_n01_LICRNA01_C01                          34.0         Dysbiotic
# A2450525897_n01_LICRNA01_E01                           5.3     Not Dysbiotic
# A2450525897_n01_LICRNA01_F01                          16.0         Dysbiotic
# ...                                                    ...               ...
# A2534491401_n01_LICRNA05_D12                          16.2         Dysbiotic
# A2534491401_n01_LICRNA05_E12                          38.0         Dysbiotic
# A2534491401_n01_LICRNA05_F12                           8.0     Not Dysbiotic
# A2534491401_n01_LICRNA05_G12                          13.0         Dysbiotic
# A2534491401_n01_LICRNA05_H12                           7.0     Not Dysbiotic
#
# [432 rows x 24 columns]

# %%
defense_gene_list
# Out:
#           gene
# 0    AT1G01100
# 1    AT1G01230
# 2    AT1G04510
# 3    AT1G07360
# 4    AT1G08450
# ..         ...
# 194  AT5G64810
# 195  AT5G65200
# 196  AT5G67300
# 197  AT5G67330
# 198  AT5G67500
#
# [199 rows x 1 columns]

# %%
transcriptome_in_defense_gene_list = trimmed_transcriptome.loc[
    :, trimmed_transcriptome.columns.isin(defense_gene_list["gene"].tolist())
]
summed_zscored_transcriptome = (
    transcriptome_in_defense_gene_list.apply(zscore).sum(axis=1) / 199
)
circadian_metadata_w_load_info = trimmed_metadata.merge(
    summed_zscored_transcriptome.rename("Summed Defense Z Score"),
    left_index=True,
    right_index=True,
)

# %%
circadian_metadata_w_load_info
# Out:
#                              plate.pos  sampID sample.type timepoint     date  \
# filename
# A2450525897_n01_LICRNA01_A01       A01  LIC001       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_B01       B01  LIC002       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_C01       C01  LIC003       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_E01       E01  LIC005       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_F01       F01  LIC006       plant       t01  11/1/23
# ...                                ...     ...         ...       ...      ...
# A2534491401_n01_LICRNA05_D12       D12  LIC542       plant    c1_t13  2/11/24
# A2534491401_n01_LICRNA05_E12       E12  LIC495       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_F12       F12  LIC421       plant    c1_t04  2/10/24
# A2534491401_n01_LICRNA05_G12       G12  LIC493       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_H12       H12  LIC505       plant    c1_t10  2/11/24
#
#                                time extractplate rnaprepplate   Unmapped  \
# filename
# A2450525897_n01_LICRNA01_A01   8:00       LIC_01    LICRNA_01  2633048.0
# A2450525897_n01_LICRNA01_B01   8:00       LIC_01    LICRNA_01  5074184.0
# A2450525897_n01_LICRNA01_C01   8:00       LIC_01    LICRNA_01  2283008.0
# A2450525897_n01_LICRNA01_E01   8:00       LIC_01    LICRNA_01  3004324.0
# A2450525897_n01_LICRNA01_F01   8:00       LIC_01    LICRNA_01  4577311.0
# ...                             ...          ...          ...        ...
# A2534491401_n01_LICRNA05_D12  20:00   LICCIRC_02    LICRNA_05  4303811.0
# A2534491401_n01_LICRNA05_E12   4:00   LICCIRC_02    LICRNA_05  4231836.0
# A2534491401_n01_LICRNA05_F12   8:00   LICCIRC_01    LICRNA_05  4885375.0
# A2534491401_n01_LICRNA05_G12   4:00   LICCIRC_02    LICRNA_05  6078838.0
# A2534491401_n01_LICRNA05_H12   8:00   LICCIRC_02    LICRNA_05  5438007.0
#
#                               No Feature  ... daysincestart  \
# filename                                  ...
# A2450525897_n01_LICRNA01_A01    112554.0  ...             0
# A2450525897_n01_LICRNA01_B01    226718.0  ...             0
# A2450525897_n01_LICRNA01_C01     97848.0  ...             0
# A2450525897_n01_LICRNA01_E01    135512.0  ...             0
# A2450525897_n01_LICRNA01_F01    113185.0  ...             0
# ...                                  ...  ...           ...
# A2534491401_n01_LICRNA05_D12    383610.0  ...           102
# A2534491401_n01_LICRNA05_E12    451686.0  ...           102
# A2534491401_n01_LICRNA05_F12    360911.0  ...           101
# A2534491401_n01_LICRNA05_G12    518084.0  ...           102
# A2534491401_n01_LICRNA05_H12    647515.0  ...           102
#
#                                    Date and Time  shannon_diversity  \
# filename
# A2450525897_n01_LICRNA01_A01 2023-11-01 08:00:00           3.372162
# A2450525897_n01_LICRNA01_B01 2023-11-01 08:00:00           3.318174
# A2450525897_n01_LICRNA01_C01 2023-11-01 08:00:00           3.624092
# A2450525897_n01_LICRNA01_E01 2023-11-01 08:00:00           2.368151
# A2450525897_n01_LICRNA01_F01 2023-11-01 08:00:00           2.417881
# ...                                          ...                ...
# A2534491401_n01_LICRNA05_D12 2024-02-11 20:00:00           3.449391
# A2534491401_n01_LICRNA05_E12 2024-02-11 04:00:00           2.617054
# A2534491401_n01_LICRNA05_F12 2024-02-10 08:00:00           2.973997
# A2534491401_n01_LICRNA05_G12 2024-02-11 04:00:00           2.894683
# A2534491401_n01_LICRNA05_H12 2024-02-11 08:00:00           2.581557
#
#                              total_species_present n_core_species_present  \
# filename
# A2450525897_n01_LICRNA01_A01                    49                     10
# A2450525897_n01_LICRNA01_B01                    51                      9
# A2450525897_n01_LICRNA01_C01                    49                     10
# A2450525897_n01_LICRNA01_E01                    31                      9
# A2450525897_n01_LICRNA01_F01                    28                      7
# ...                                            ...                    ...
# A2534491401_n01_LICRNA05_D12                    51                     10
# A2534491401_n01_LICRNA05_E12                    35                      8
# A2534491401_n01_LICRNA05_F12                    33                     10
# A2534491401_n01_LICRNA05_G12                    40                     10
# A2534491401_n01_LICRNA05_H12                    33                      9
#
#                               has_rare_species lacking_core_species  \
# filename
# A2450525897_n01_LICRNA01_A01              True                False
# A2450525897_n01_LICRNA01_B01              True                 True
# A2450525897_n01_LICRNA01_C01              True                False
# A2450525897_n01_LICRNA01_E01              True                 True
# A2450525897_n01_LICRNA01_F01              True                 True
# ...                                        ...                  ...
# A2534491401_n01_LICRNA05_D12              True                False
# A2534491401_n01_LICRNA05_E12              True                 True
# A2534491401_n01_LICRNA05_F12              True                False
# A2534491401_n01_LICRNA05_G12              True                False
# A2534491401_n01_LICRNA05_H12              True                 True
#
#                               rare_species_total_abundR100  Dysbiosis Status  \
# filename
# A2450525897_n01_LICRNA01_A01                          11.7         Dysbiotic
# A2450525897_n01_LICRNA01_B01                          20.8         Dysbiotic
# A2450525897_n01_LICRNA01_C01                          34.0         Dysbiotic
# A2450525897_n01_LICRNA01_E01                           5.3     Not Dysbiotic
# A2450525897_n01_LICRNA01_F01                          16.0         Dysbiotic
# ...                                                    ...               ...
# A2534491401_n01_LICRNA05_D12                          16.2         Dysbiotic
# A2534491401_n01_LICRNA05_E12                          38.0         Dysbiotic
# A2534491401_n01_LICRNA05_F12                           8.0     Not Dysbiotic
# A2534491401_n01_LICRNA05_G12                          13.0         Dysbiotic
# A2534491401_n01_LICRNA05_H12                           7.0     Not Dysbiotic
#
#                               Summed Defense Z Score
# filename
# A2450525897_n01_LICRNA01_A01                1.380830
# A2450525897_n01_LICRNA01_B01                0.854986
# A2450525897_n01_LICRNA01_C01                2.293520
# A2450525897_n01_LICRNA01_E01                0.620171
# A2450525897_n01_LICRNA01_F01                2.585703
# ...                                              ...
# A2534491401_n01_LICRNA05_D12               -0.005808
# A2534491401_n01_LICRNA05_E12               -0.526801
# A2534491401_n01_LICRNA05_F12                0.384903
# A2534491401_n01_LICRNA05_G12                0.219473
# A2534491401_n01_LICRNA05_H12               -0.200636
#
# [432 rows x 25 columns]

# %%
circadian_metadata_w_load_info.groupby("Dysbiosis Status")[
    "Summed Defense Z Score"
].mean()
# Out:
# Dysbiosis Status
# Dysbiotic        0.290438
# Not Dysbiotic   -0.045041
# Name: Summed Defense Z Score, dtype: float64

# %%
dysbiotic_scores = circadian_metadata_w_load_info.loc[
    circadian_metadata_w_load_info["Dysbiosis Status"] == "Dysbiotic",
    "Summed Defense Z Score",
]
nondysbiotic_scores = circadian_metadata_w_load_info.loc[
    circadian_metadata_w_load_info["Dysbiosis Status"] == "Not Dysbiotic",
    "Summed Defense Z Score",
]

# %%
nondysbiotic_scores
# Out:
# filename
# A2450525897_n01_LICRNA01_E01    0.620171
# A2450525897_n01_LICRNA01_D02    0.736609
# A2450525897_n01_LICRNA01_G02    0.636374
# A2450525897_n01_LICRNA01_A03    0.859542
# A2450525897_n01_LICRNA01_C03    0.883993
#                                   ...
# A2534491401_n01_LICRNA05_H11    1.666311
# A2534491401_n01_LICRNA05_A12   -0.412131
# A2534491401_n01_LICRNA05_C12    2.029617
# A2534491401_n01_LICRNA05_F12    0.384903
# A2534491401_n01_LICRNA05_H12   -0.200636
# Name: Summed Defense Z Score, Length: 374, dtype: float64

# %%
dysbiotic_scores
# Out:
# filename
# A2450525897_n01_LICRNA01_A01    1.380830
# A2450525897_n01_LICRNA01_B01    0.854986
# A2450525897_n01_LICRNA01_C01    2.293520
# A2450525897_n01_LICRNA01_F01    2.585703
# A2450525897_n01_LICRNA01_H01    1.257090
# A2450525897_n01_LICRNA01_B02   -0.269317
# A2450525897_n01_LICRNA01_E02    0.618252
# A2450525897_n01_LICRNA01_F02    1.154324
# A2450525897_n01_LICRNA01_B03    0.233867
# A2450525897_n01_LICRNA01_B04    0.265187
# A2450525897_n01_LICRNA01_A05    0.396618
# A2450525897_n01_LICRNA01_B05   -0.153005
# A2450525897_n01_LICRNA01_D05    0.861798
# A2450525897_n01_LICRNA01_F05    0.491066
# A2450525897_n01_LICRNA01_E06    0.256695
# A2450525897_n01_LICRNA01_F06    0.139946
# A2450525897_n01_LICRNA01_A07    0.434013
# A2450525897_n01_LICRNA01_F07    0.063289
# A2450525897_n01_LICRNA01_B08   -0.255093
# A2450525897_n01_LICRNA01_C08    0.096198
# A2450525897_n01_LICRNA01_E08   -0.151891
# A2450525897_n01_LICRNA01_E10   -0.147122
# A2450525897_n01_LICRNA01_B11    0.214090
# A2450525897_n01_LICRNA01_H11    0.338050
# A2450525897_n01_LICRNA01_E12    0.074074
# A2449446903_n01_LICRNA02_E01    0.343036
# A2449446903_n01_LICRNA02_H04   -0.323212
# A2449446903_n01_LICRNA02_C07    0.025464
# A2449446903_n01_LICRNA02_F10   -0.485241
# A2449446903_n01_LICRNA02_E12   -0.173081
# B250508004_n01_LICRNA03_G01    -0.409283
# B250508004_n01_LICRNA03_D04    -0.609517
# B250508004_n01_LICRNA03_G04    -0.167112
# B2449500127_n01_LICRNA04_C06   -0.215925
# B2449500127_n01_LICRNA04_D07   -0.208091
# B2449500127_n01_LICRNA04_C09   -0.349450
# B2449500127_n01_LICRNA04_B10   -0.368154
# B2449500127_n01_LICRNA04_E11   -0.658272
# B2449500127_n01_LICRNA04_F12    0.048389
# A2534491401_n01_LICRNA05_A01    0.030788
# A2534491401_n01_LICRNA05_F02    0.311976
# A2534491401_n01_LICRNA05_B03   -0.373218
# A2534491401_n01_LICRNA05_F07   -0.049814
# A2534491401_n01_LICRNA05_A08    0.331002
# A2534491401_n01_LICRNA05_B08    0.360844
# A2534491401_n01_LICRNA05_D08    0.445925
# A2534491401_n01_LICRNA05_F08    0.743640
# A2534491401_n01_LICRNA05_G08    0.047579
# A2534491401_n01_LICRNA05_G09   -0.159485
# A2534491401_n01_LICRNA05_D10    1.215820
# A2534491401_n01_LICRNA05_E10    0.010505
# A2534491401_n01_LICRNA05_H10    1.409943
# A2534491401_n01_LICRNA05_B11   -0.111880
# A2534491401_n01_LICRNA05_E11    0.581926
# A2534491401_n01_LICRNA05_B12    2.880297
# A2534491401_n01_LICRNA05_D12   -0.005808
# A2534491401_n01_LICRNA05_E12   -0.526801
# A2534491401_n01_LICRNA05_G12    0.219473
# Name: Summed Defense Z Score, dtype: float64

# %%
ttest_ind(a=dysbiotic_scores, b=nondysbiotic_scores)
# Out:
# TtestResult(statistic=np.float64(4.471139031239851), pvalue=np.float64(9.967291892417754e-06), df=np.float64(430.0))

# %%
sns.boxplot(
    data=circadian_metadata_w_load_info,
    x="Dysbiosis Status",
    y="Summed Defense Z Score",
)
# Out:
# <Axes: xlabel='Dysbiosis Status', ylabel='Summed Defense Z Score'>

# %%
circadian_metadata_w_load_info
# Out:
#                              plate.pos  sampID sample.type timepoint     date  \
# filename
# A2450525897_n01_LICRNA01_A01       A01  LIC001       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_B01       B01  LIC002       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_C01       C01  LIC003       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_E01       E01  LIC005       plant       t01  11/1/23
# A2450525897_n01_LICRNA01_F01       F01  LIC006       plant       t01  11/1/23
# ...                                ...     ...         ...       ...      ...
# A2534491401_n01_LICRNA05_D12       D12  LIC542       plant    c1_t13  2/11/24
# A2534491401_n01_LICRNA05_E12       E12  LIC495       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_F12       F12  LIC421       plant    c1_t04  2/10/24
# A2534491401_n01_LICRNA05_G12       G12  LIC493       plant    c1_t09  2/11/24
# A2534491401_n01_LICRNA05_H12       H12  LIC505       plant    c1_t10  2/11/24
#
#                                time extractplate rnaprepplate   Unmapped  \
# filename
# A2450525897_n01_LICRNA01_A01   8:00       LIC_01    LICRNA_01  2633048.0
# A2450525897_n01_LICRNA01_B01   8:00       LIC_01    LICRNA_01  5074184.0
# A2450525897_n01_LICRNA01_C01   8:00       LIC_01    LICRNA_01  2283008.0
# A2450525897_n01_LICRNA01_E01   8:00       LIC_01    LICRNA_01  3004324.0
# A2450525897_n01_LICRNA01_F01   8:00       LIC_01    LICRNA_01  4577311.0
# ...                             ...          ...          ...        ...
# A2534491401_n01_LICRNA05_D12  20:00   LICCIRC_02    LICRNA_05  4303811.0
# A2534491401_n01_LICRNA05_E12   4:00   LICCIRC_02    LICRNA_05  4231836.0
# A2534491401_n01_LICRNA05_F12   8:00   LICCIRC_01    LICRNA_05  4885375.0
# A2534491401_n01_LICRNA05_G12   4:00   LICCIRC_02    LICRNA_05  6078838.0
# A2534491401_n01_LICRNA05_H12   8:00   LICCIRC_02    LICRNA_05  5438007.0
#
#                               No Feature  ... daysincestart  \
# filename                                  ...
# A2450525897_n01_LICRNA01_A01    112554.0  ...             0
# A2450525897_n01_LICRNA01_B01    226718.0  ...             0
# A2450525897_n01_LICRNA01_C01     97848.0  ...             0
# A2450525897_n01_LICRNA01_E01    135512.0  ...             0
# A2450525897_n01_LICRNA01_F01    113185.0  ...             0
# ...                                  ...  ...           ...
# A2534491401_n01_LICRNA05_D12    383610.0  ...           102
# A2534491401_n01_LICRNA05_E12    451686.0  ...           102
# A2534491401_n01_LICRNA05_F12    360911.0  ...           101
# A2534491401_n01_LICRNA05_G12    518084.0  ...           102
# A2534491401_n01_LICRNA05_H12    647515.0  ...           102
#
#                                    Date and Time  shannon_diversity  \
# filename
# A2450525897_n01_LICRNA01_A01 2023-11-01 08:00:00           3.372162
# A2450525897_n01_LICRNA01_B01 2023-11-01 08:00:00           3.318174
# A2450525897_n01_LICRNA01_C01 2023-11-01 08:00:00           3.624092
# A2450525897_n01_LICRNA01_E01 2023-11-01 08:00:00           2.368151
# A2450525897_n01_LICRNA01_F01 2023-11-01 08:00:00           2.417881
# ...                                          ...                ...
# A2534491401_n01_LICRNA05_D12 2024-02-11 20:00:00           3.449391
# A2534491401_n01_LICRNA05_E12 2024-02-11 04:00:00           2.617054
# A2534491401_n01_LICRNA05_F12 2024-02-10 08:00:00           2.973997
# A2534491401_n01_LICRNA05_G12 2024-02-11 04:00:00           2.894683
# A2534491401_n01_LICRNA05_H12 2024-02-11 08:00:00           2.581557
#
#                              total_species_present n_core_species_present  \
# filename
# A2450525897_n01_LICRNA01_A01                    49                     10
# A2450525897_n01_LICRNA01_B01                    51                      9
# A2450525897_n01_LICRNA01_C01                    49                     10
# A2450525897_n01_LICRNA01_E01                    31                      9
# A2450525897_n01_LICRNA01_F01                    28                      7
# ...                                            ...                    ...
# A2534491401_n01_LICRNA05_D12                    51                     10
# A2534491401_n01_LICRNA05_E12                    35                      8
# A2534491401_n01_LICRNA05_F12                    33                     10
# A2534491401_n01_LICRNA05_G12                    40                     10
# A2534491401_n01_LICRNA05_H12                    33                      9
#
#                               has_rare_species lacking_core_species  \
# filename
# A2450525897_n01_LICRNA01_A01              True                False
# A2450525897_n01_LICRNA01_B01              True                 True
# A2450525897_n01_LICRNA01_C01              True                False
# A2450525897_n01_LICRNA01_E01              True                 True
# A2450525897_n01_LICRNA01_F01              True                 True
# ...                                        ...                  ...
# A2534491401_n01_LICRNA05_D12              True                False
# A2534491401_n01_LICRNA05_E12              True                 True
# A2534491401_n01_LICRNA05_F12              True                False
# A2534491401_n01_LICRNA05_G12              True                False
# A2534491401_n01_LICRNA05_H12              True                 True
#
#                               rare_species_total_abundR100  Dysbiosis Status  \
# filename
# A2450525897_n01_LICRNA01_A01                          11.7         Dysbiotic
# A2450525897_n01_LICRNA01_B01                          20.8         Dysbiotic
# A2450525897_n01_LICRNA01_C01                          34.0         Dysbiotic
# A2450525897_n01_LICRNA01_E01                           5.3     Not Dysbiotic
# A2450525897_n01_LICRNA01_F01                          16.0         Dysbiotic
# ...                                                    ...               ...
# A2534491401_n01_LICRNA05_D12                          16.2         Dysbiotic
# A2534491401_n01_LICRNA05_E12                          38.0         Dysbiotic
# A2534491401_n01_LICRNA05_F12                           8.0     Not Dysbiotic
# A2534491401_n01_LICRNA05_G12                          13.0         Dysbiotic
# A2534491401_n01_LICRNA05_H12                           7.0     Not Dysbiotic
#
#                               Summed Defense Z Score
# filename
# A2450525897_n01_LICRNA01_A01                1.380830
# A2450525897_n01_LICRNA01_B01                0.854986
# A2450525897_n01_LICRNA01_C01                2.293520
# A2450525897_n01_LICRNA01_E01                0.620171
# A2450525897_n01_LICRNA01_F01                2.585703
# ...                                              ...
# A2534491401_n01_LICRNA05_D12               -0.005808
# A2534491401_n01_LICRNA05_E12               -0.526801
# A2534491401_n01_LICRNA05_F12                0.384903
# A2534491401_n01_LICRNA05_G12                0.219473
# A2534491401_n01_LICRNA05_H12               -0.200636
#
# [432 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))
fig.patch.set_facecolor("white")
ax = sns.violinplot(
    data=circadian_metadata_w_load_info,
    x="Dysbiosis Status",
    y="Summed Defense Z Score",
    inner="box",
    common_norm=True,
)
plt.xlabel("Dysbiosis Status", fontsize=14)
plt.ylabel("Defense Activation Score", fontsize=14)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
# ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(
    fontsize=10,
)  # rotation=90
plt.yticks(fontsize=10)
plt.ylim(-1.7, 5)
plt.tight_layout()
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
# for line in range(0,full_meta_data.shape[0]):
#      ax.text(pca[:,0][line]+0.01, pca[:,1][line],
#      full_meta_data['plate.pos'][line], horizontalalignment='left',
#      size='medium', color='black', weight='semibold')

# %%
circadian_metadata_w_load_info.groupby("Dysbiosis Status")[
    "Summed Defense Z Score"
].median()
# Out:
# Dysbiosis Status
# Dysbiotic        0.085136
# Not Dysbiotic   -0.144157
# Name: Summed Defense Z Score, dtype: float64

# %%
circadian_metadata_w_load_info.to_csv(
    "/Users/michael/Library/CloudStorage/GoogleDrive-mikepassalacqua@gmail.com/My Drive/Bergleson Lab Documents/Luke Terrace/All_used_and_generated_terrace_data/Stats_7_28_Files/dysbiosis_status_and_defense_score.csv",
    index=True,
)

# %%
t_stat, p_value = ttest_ind(dysbiotic_scores, nondysbiotic_scores)
print(f"P-value: {p_value}")
# Out:
# P-value: 9.967291892417754e-06

# %%
t14_and_later = circadian_metadata_w_load_info.loc[
    pd.to_numeric(
        circadian_metadata_w_load_info["timepoint"]
        .astype(str)
        .str.extract(r"(\d+)", expand=False),
        errors="coerce",
    )
    >= 14
]

fig, ax = plt.subplots(figsize=(5, 5))
fig.patch.set_facecolor("white")
ax = sns.violinplot(
    data=t14_and_later,
    x="Dysbiosis Status",
    y="Summed Defense Z Score",
    inner="box",
    common_norm=True,
)
plt.xlabel("Dysbiosis Status", fontsize=14)
plt.ylabel("Defense Activation Score", fontsize=14)
plt.title("T14 and Later", fontsize=14)
sns.despine()
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
plt.xticks(
    fontsize=10,
)  # rotation=90
plt.yticks(fontsize=10)
plt.ylim(-1.7, 5)
plt.tight_layout()

# %%
t14_and_later.groupby("Dysbiosis Status")["Summed Defense Z Score"].count()
# Out:
# Dysbiosis Status
# Dysbiotic         14
# Not Dysbiotic    103
# Name: Summed Defense Z Score, dtype: int64

# %%
circadian_only = circadian_metadata_w_load_info.loc[
    circadian_metadata_w_load_info["Experiment Type"].isin(
        ["Circadian Experiment 1", "Circadian Experiment 2"]
    )
]

fig, ax = plt.subplots(figsize=(6, 5))
fig.patch.set_facecolor("white")
ax = sns.violinplot(
    data=circadian_only,
    x="Dysbiosis Status",
    y="Summed Defense Z Score",
    hue="Experiment Type",
    inner="box",
    common_norm=True,
    split=True,
)
plt.xlabel("Dysbiosis Status", fontsize=14)
plt.ylabel("Defense Activation Score", fontsize=14)
plt.title("Circadian Samples", fontsize=14)
sns.despine()
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
plt.xticks(
    fontsize=10,
)  # rotation=90
plt.yticks(fontsize=10)
plt.ylim(-1.7, 5)
plt.legend(title="Experiment Type", frameon=False)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(40, 10))
fig.patch.set_facecolor("white")
ax = sns.violinplot(
    data=circadian_metadata_w_load_info,
    x="timepoint",
    y="Summed Defense Z Score",
    hue="Dysbiosis Status",
    width=3,
    split=True,
    inner="box",
)
plt.xlabel("Hours Since Heavy Rain (>1mm/hr)", fontsize=14)
plt.ylabel("Defense Activation Score", fontsize=14)
sns.despine()
# ax.grid(False)
# plt.axhline(1, color = 'red', linestyle = 'dashed')
ax.spines["bottom"].set_color("black")
ax.spines["bottom"].set_linewidth(2)
ax.spines["left"].set_color("black")
ax.spines["left"].set_linewidth(2)
ax.tick_params(axis="both", width=2)
# plt.xlim((0,3))
# plt.ylim((0, 3))
# handles, labels  =  ax.get_legend_handles_labels()
# ax.legend(loc="upper right")
# plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(
    fontsize=10,
)  # rotation=90
plt.yticks(fontsize=10)
# plt.ylim(-.02,1)
plt.tight_layout()
# ax.plot([0,1],[0,1], transform=ax.transAxes, linestyle = 'dashed', color = 'k', linewidth = 1.5)
# for line in range(0,full_meta_data.shape[0]):
#      ax.text(pca[:,0][line]+0.01, pca[:,1][line],
#      full_meta_data['plate.pos'][line], horizontalalignment='left',
#      size='medium', color='black', weight='semibold')
