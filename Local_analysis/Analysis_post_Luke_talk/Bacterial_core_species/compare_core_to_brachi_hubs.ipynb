# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
core_results = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/Generated_data/species_core_results.csv"
)
core_results.loc[core_results["core"] == True,]
# Out:
#                              Species  n_samples_present  \
# 0            Kordiimonas sp002401685                372
# 1  Sphingomonas_L_486704 sp000786205                372
# 2             Rhodoferax_C aquaticus                370
# 3                  Neorhizobium soli                366
# 4                Klenkia sp001424455                363
# 5              Massilia atriviolacea                353
# 6             Variovorax paradoxus_C                340
# 7            Flavobacterium chilense                328
# 8         Sphingomonas_L_486704 taxi                319
# 9       Frigoribacterium sp001424645                298
#
#    mean_abundance_present  median_abundance_present  prevalence  core
# 0                3.661053                      3.30    1.000000  True
# 1               17.954211                     15.90    1.000000  True
# 2                4.407143                      3.70    0.994624  True
# ...

# %%
####Kordiimonas - not there, not real? Why is it present in 100 percent samples
## Sphingomonas - present in hub
## Rhodoferax - not in hub
## Neorhizobium - present in hub
## Klenkia - not in hub
## Massillia - present in hub
## Variovorax - present in hub
## Flavobacterium - not in hub
### Frigoribacterium - Not in hub

# %%
hub_genes_brachi = pd.read_csv(
    "/Users/michael/Data/Luke_terrace_experiment/General_data/hub_info_brachi_paper.csv",
    sep="\t",
)
hub_genes_brachi = hub_genes_brachi.loc[
    (hub_genes_brachi["hub"] > 0) & (hub_genes_brachi["domain"] == "Bacteria")
]
hub_genes_brachi
# Out:
#       OTU  heritable  hub  heritable hub  Nexp  Core microbiota  \
# 0      B1          2    2              0     8                1
# 4    B102          0    1              0     5                0
# 10   B107          1    1              1     5                0
# 15   B111          1    1              0     8                1
# 20   B116          0    1              0     5                0
# 23   B118          0    1              0     7                0
# 25    B12          5    3              1     8                1
# 36    B13          4    1              1     8                1
# 46   B139          0    2              0     5                0
# 56   B148          0    3              0     0                0
# 67   B158          0    1              0     3                0
# 91    B18          1    2              0     8                1
# 101  B189          2    1              0     2                0
# 148  B230          0    1              0     3                0
# ...
