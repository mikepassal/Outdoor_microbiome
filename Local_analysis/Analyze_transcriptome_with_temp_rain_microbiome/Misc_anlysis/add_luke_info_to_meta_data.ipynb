# %%
import pandas as pd

# %%
luke_new_metadata = pd.read_csv('/Users/michael/Data/Luke_terrace_experiment/Microbiome/lic2024_pooled_meta.tsv', sep = '\t', skiprows = [1])
luke_new_metadata
# Out:
#     sample-id sample.type timepoint     date  time platename  daysincestart
# 0      LIC001       plant       t01  11/1/23  8:00    LIC_01              0
# 1      LIC002       plant       t01  11/1/23  8:00    LIC_01              0
# 2      LIC003       plant       t01  11/1/23  8:00    LIC_01              0
# 3      LIC004       plant       t01  11/1/23  8:00    LIC_01              0
# 4      LIC005       plant       t01  11/1/23  8:00    LIC_01              0
# ..        ...         ...       ...      ...   ...       ...            ...
# 603  t24_soil        soil       t24   3/1/24  8:00    LIC_04            121
# 604  t25_soil        soil       t25   3/5/24  8:00    LIC_04            125
# 605  t26_soil        soil       t26   3/8/24  8:00    LIC_04            128
# 606  t27_soil        soil       t27  3/12/24  8:00    LIC_04            132
# 607  t28_soil        soil       t28  3/14/24  8:00    LIC_04            134
#
# [608 rows x 7 columns]

# %%
full_meta_data = pd.read_csv('/Users/michael/Data/Luke_terrace_experiment/General_data/Plates_1_to_4_metadata.csv')
#full_meta_data = full_meta_data.set_index('filename', drop = True)
full_meta_data = full_meta_data.drop_duplicates()
full_meta_data['Experiment Type'] = full_meta_data['timepoint'].str.split('t').str[0]
full_meta_data = full_meta_data.replace('', 'Long Term')
full_meta_data = full_meta_data.replace('c1_', 'Circadian Experiment 1')
full_meta_data = full_meta_data.replace('c2_', 'Circadian Experiment 2')
full_meta_data['Sample Month'] = full_meta_data['date'].str.split('/').str[0]
full_meta_data = full_meta_data.replace({'11':'November', '12':'December', '1':'January', '2':'February', '3':'March', '4':'April'})
full_meta_data
# Out:
#                          filename plate.pos  arb.sort  sampID sample.type  \
# 0    A2450525897_n01_LICRNA01_A01       A01         1  LIC001       plant
# 1    A2450525897_n01_LICRNA01_B01       B01         2  LIC002       plant
# 2    A2450525897_n01_LICRNA01_C01       C01         3  LIC003       plant
# 3    A2450525897_n01_LICRNA01_D01       D01         4  LIC004       plant
# 4    A2450525897_n01_LICRNA01_E01       E01         5  LIC005       plant
# ..                            ...       ...       ...     ...         ...
# 379  B2449500127_n01_LICRNA04_D12       D12        92  LIC640       plant
# 380  B2449500127_n01_LICRNA04_E12       E12        93  LIC641       plant
# 381  B2449500127_n01_LICRNA04_F12       F12        94  LIC642       plant
# 382  B2449500127_n01_LICRNA04_G12       G12        95  LIC643       plant
# 383  B2449500127_n01_LICRNA04_H12       H12        96  LIC644       plant
#
#     timepoint     date   time extractplate rnaprepplate  ...  Multimapping  \
# ...

# %%
old_metadata = full_meta_data

# %%
plant_luke_metadata = luke_new_metadata.loc[luke_new_metadata['sample.type'] == 'plant']
plant_luke_metadata.tail(20)
# Out:
#     sample-id sample.type timepoint    date   time   platename  daysincestart
# 522    LIC725       plant    c2_t11  3/3/24  12:00  LICCIRC_04            123
# 523    LIC726       plant    c2_t11  3/3/24  12:00  LICCIRC_04            123
# 524    LIC727       plant    c2_t11  3/3/24  12:00  LICCIRC_04            123
# 525    LIC728       plant    c2_t11  3/3/24  12:00  LICCIRC_04            123
# 526    LIC733       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 527    LIC734       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 528    LIC735       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 529    LIC736       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 530    LIC737       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 531    LIC738       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# 532    LIC739       plant    c2_t12  3/3/24  16:00  LICCIRC_04            123
# ...

# %%
merged_meta_data_first_4_plates
# Out:
#                          filename plate.pos  arb.sort  sampID sample.type  \
# 0    A2450525897_n01_LICRNA01_A01       A01         1  LIC001       plant
# 1    A2450525897_n01_LICRNA01_B01       B01         2  LIC002       plant
# 2    A2450525897_n01_LICRNA01_C01       C01         3  LIC003       plant
# 3    A2450525897_n01_LICRNA01_D01       D01         4  LIC004       plant
# 4    A2450525897_n01_LICRNA01_E01       E01         5  LIC005       plant
# ..                            ...       ...       ...     ...         ...
# 379  B2449500127_n01_LICRNA04_D12       D12        92  LIC640       plant
# 380  B2449500127_n01_LICRNA04_E12       E12        93  LIC641       plant
# 381  B2449500127_n01_LICRNA04_F12       F12        94  LIC642       plant
# 382  B2449500127_n01_LICRNA04_G12       G12        95  LIC643       plant
# 383  B2449500127_n01_LICRNA04_H12       H12        96  LIC644       plant
#
#     timepoint     date   time extractplate rnaprepplate  ...  \
# ...

# %%
merged_meta_data_first_4_plates = old_metadata.merge(luke_new_metadata[['sample-id','daysincestart']], left_on='sampID', right_on= 'sample-id')
merged_meta_data_first_4_plates.to_csv('/Users/michael/Data/Luke_terrace_experiment/General_data/Plates_1_to_4_metadata_merged_luke.csv', index=False )
